# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import PowerTransformer, StandardScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_squared_log_error, make_scorer
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from functools import partial

# 1. Caricamento dati
df_train = pd.read_csv('/content/drive/MyDrive/data_calories/train.csv')
df_test  = pd.read_csv('/content/drive/MyDrive/data_calories/test.csv')

# 2. Feature engineering avanzato
def make_features(df):
    df = df.copy()
    df['Sex']               = df['Sex'].map({'male': 0, 'female': 1})
    df['BMI']               = df['Weight'] / (df['Height'] / 100) ** 2
    df['BSA']               = 0.007184 * df['Weight']**0.425 * df['Height']**0.725
    df['Delta_Temp']        = df['Body_Temp'] - 37.0
    df['HR_per_kg']         = df['Heart_Rate'] / df['Weight']
    df['Heart_Beats_Total'] = df['Heart_Rate'] * df['Duration']
    # Interazioni aggiuntive
    df['BMI_x_Duration']    = df['BMI'] * df['Duration']
    df['HBT_per_BSA']       = df['Heart_Beats_Total'] / df['BSA']
    df['BMI_squared']       = df['BMI'] ** 2
    return df

train_fe = make_features(df_train)
test_fe  = make_features(df_test)

# 3. EDA rapida per verificare le feature (opzionale, commentato per esecuzione)
"""
plt.figure(figsize=(12, 8))
corr = train_fe.drop('id', axis=1).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matrice di Correlazione')
plt.tight_layout()
plt.show()
"""

# 4. Definizione di X e y
X = train_fe.drop(columns=['id', 'Calories'])
y = train_fe['Calories']
X_test_raw = test_fe.drop(columns=['id'])

# 5. Identificazione delle feature asimmetriche
skew_thresh  = 0.75
skewness     = X.skew().abs()
skewed_feats = skewness[skewness > skew_thresh].index.tolist()
pos_feats    = [f for f in skewed_feats if (X[f] > 0).all()]
nonpos_feats = [f for f in skewed_feats if f not in pos_feats]

# 6. Preprocessing
# 6.1 Fit del PowerTransformer sui nonpos_feats
pt = None
if nonpos_feats:
    pt = PowerTransformer(method='yeo-johnson', standardize=False)
    pt.fit(X[nonpos_feats])

# 6.2 Trasformazione log1p per pos_feats e PowerTransformer per nonpos_feats
X_p = X.copy()
for f in pos_feats:
    X_p[f] = np.log1p(X_p[f])
if nonpos_feats:
    X_p[nonpos_feats] = pt.transform(X_p[nonpos_feats])

# 6.3 Robust Scaling
scaler = RobustScaler()
scaler.fit(X_p)
X_proc = pd.DataFrame(scaler.transform(X_p), columns=X.columns, index=X.index)

# 6.4 Preprocessing del test set
X_test_p = X_test_raw.copy()
for f in pos_feats:
    X_test_p[f] = np.log1p(X_test_p[f])
if nonpos_feats:
    X_test_p[nonpos_feats] = pt.transform(X_test_p[nonpos_feats])
X_test_proc = pd.DataFrame(scaler.transform(X_test_p), columns=X_test_p.columns)

# 7. Log-transform del target
y_log = np.log1p(y)

# 8. Definizione dello split per hold-out (10%)
X_train_main, X_hold, y_train_main, y_hold = train_test_split(
    X_proc, y_log, test_size=0.1, random_state=42
)

# 9. Iperparametri ottimali da Optuna (trial 17)
best_params = {
    'learning_rate':    0.004523596335091698,
    'max_depth':        9,
    'subsample':        0.9708888609967907,
    'colsample_bytree': 0.7684560546712256,
    'min_child_weight': 5,
    'reg_alpha':        2.9753791923207157e-05,
    'reg_lambda':       2.986233138083534
}

# 10. Definizione metrica custom RMSLE per cross-validation
def rmsle_scorer(y_true, y_pred):
    y_true_exp = np.expm1(y_true)
    y_pred_exp = np.expm1(y_pred)
    return np.sqrt(mean_squared_log_error(y_true_exp, y_pred_exp))

custom_rmsle_scorer = make_scorer(rmsle_scorer, greater_is_better=False)

# 11. Cross-validation con KFold
n_folds = 5
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)

# Inizializzazione del modello base per CV
cv_model = XGBRegressor(
    objective='reg:squarederror',
    eval_metric='rmse',
    random_state=42,
    **best_params
)

# Esecuzione CV sul training set principale (escludendo hold-out)
cv_results = cross_val_score(
    cv_model,
    X_train_main,
    y_train_main,
    cv=kf,
    scoring=custom_rmsle_scorer,
    n_jobs=-1,
    verbose=1
)

# Stampa risultati CV
cv_rmsle_scores = -cv_results  # Converto da negative a positive scores
print(f"Cross-Validation RMSLE Scores: {cv_rmsle_scores}")
print(f"Mean CV RMSLE: {cv_rmsle_scores.mean():.4f}, Std: {cv_rmsle_scores.std():.4f}")

# 12. Allenamento con early stopping su hold-out
model_es = XGBRegressor(
    objective='reg:squarederror',
    eval_metric='rmse',
    random_state=42,
    n_estimators=2000,
    early_stopping_rounds=50,
    verbosity=1,
    **best_params
)
model_es.fit(
    X_train_main, y_train_main,
    eval_set=[(X_hold, y_hold)],
    verbose=True
)

print(f"Numero ottimale di boosting rounds: {model_es.best_iteration}")

# 13. Valutazione su hold-out
y_pred_log = model_es.predict(X_hold)
y_pred     = np.expm1(y_pred_log)
y_true     = np.expm1(y_hold)
rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
rmsle = np.sqrt(mean_squared_log_error(y_true, y_pred))
print(f"Hold-out → RMSE: {rmse:.4f}, RMSLE: {rmsle:.4f}")

# 14. Re-fit su tutto il training set con CV ensemble
final_models = []
fold_predictions = []

print("\nAddestramento modelli CV ensemble...")
for fold, (train_idx, val_idx) in enumerate(kf.split(X_proc)):
    print(f"\nTraining fold {fold+1}/{n_folds}")
    X_train_fold, X_val_fold = X_proc.iloc[train_idx], X_proc.iloc[val_idx]
    y_train_fold, y_val_fold = y_log.iloc[train_idx], y_log.iloc[val_idx]

    # Modello fold con early stopping interno
    fold_model = XGBRegressor(
        objective='reg:squarederror',
        eval_metric='rmse',
        random_state=42,
        n_estimators=model_es.best_iteration,  # Numero di round ottimale trovato precedentemente
        verbosity=1,
        **best_params
    )

    # Fit con early stopping su validation set del fold
    fold_model.fit(
        X_train_fold, y_train_fold,
        eval_set=[(X_val_fold, y_val_fold)],
        verbose=False
    )

    # Validazione fold
    fold_preds = fold_model.predict(X_val_fold)
    fold_preds_exp = np.expm1(fold_preds)
    fold_true_exp = np.expm1(y_val_fold)
    fold_rmsle = np.sqrt(mean_squared_log_error(fold_true_exp, fold_preds_exp))
    print(f"Fold {fold+1} RMSLE: {fold_rmsle:.4f}")

    # Salvare previsioni e modello
    fold_predictions.append((val_idx, fold_preds))
    final_models.append(fold_model)

# 15. Validazione OOF (Out-of-fold)
oof_true_indices = np.concatenate([idx for idx, _ in fold_predictions])
oof_preds = np.concatenate([pred for _, pred in sorted(fold_predictions, key=lambda x: x[0][0])])
oof_preds_exp = np.expm1(oof_preds)
oof_true_exp = np.expm1(y_log.iloc[oof_true_indices])

oof_rmsle = np.sqrt(mean_squared_log_error(oof_true_exp, oof_preds_exp))
print(f"\nOut-of-fold RMSLE: {oof_rmsle:.4f}")

# 16. Previsioni finali (media degli ensemble models)
test_preds = []
for model in final_models:
    test_pred = model.predict(X_test_proc)
    test_preds.append(test_pred)

# Media delle previsioni log-scale e trasformazione inversa
y_test_log_ensemble = np.mean(test_preds, axis=0)
y_test_ensemble = np.expm1(y_test_log_ensemble)

# 17. Feature importance media
importance_df = pd.DataFrame()
importance_df['Feature'] = X.columns
importance_df['Importance'] = np.mean([model.feature_importances_ for model in final_models], axis=0)
importance_df = importance_df.sort_values('Importance', ascending=False).reset_index(drop=True)

print("\nTop 10 feature importances:")
print(importance_df.head(10))

# 18. Creazione submission
df_test['Pred_Calories'] = y_test_ensemble
df_test[['id', 'Pred_Calories']].to_csv('submission.csv', index=False)
print("\nPreview delle predizioni:")
print(df_test[['id', 'Pred_Calories']].head())

submission = pd.read_csv('/content/drive/MyDrive/data_calories/sample_submission.csv')
submission['Calories'] = df_test['Pred_Calories']
submission.to_csv('/content/drive/MyDrive/data_calories/submission_cv_ensemble.csv', index=False)
print("\nCreato file pronto per il submit con ensemble CV!")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.2min finished
# Cross-Validation RMSLE Scores: [0.61675712 0.61695073 0.6189664  0.61474752 0.61783528]
# Mean CV RMSLE: 0.6171, Std: 0.0014
# [0]	validation_0-rmse:0.96015
# [1]	validation_0-rmse:0.95587
# [2]	validation_0-rmse:0.95164
# [3]	validation_0-rmse:0.94738
# [4]	validation_0-rmse:0.94314
# [5]	validation_0-rmse:0.93893
# [6]	validation_0-rmse:0.93472
# [7]	validation_0-rmse:0.93055
# [8]	validation_0-rmse:0.92644
# [9]	validation_0-rmse:0.92229
# [10]	validation_0-rmse:0.91817
# [11]	validation_0-rmse:0.91406
# [12]	validation_0-rmse:0.91002
# [13]	validation_0-rmse:0.90599
# [14]	validation_0-rmse:0.90194
# [15]	validation_0-rmse:0.89792
# [16]	validation_0-rmse:0.89394
# [17]	validation_0-rmse:0.88994
# [18]	validation_0-rmse:0.88596
# [19]	validation_0-rmse:0.88205
# [20]	validation_0-rmse:0.87815
# [21]	validation_0-rmse:0.87422
# [22]	validation_0-rmse:0.87033
# [23]	validation_0-rmse:0.86648
# [24]	validation_0-rmse:0.86261
# [25]	validation_0-rmse:0.85876
# [26]	validation_0-rmse:0.85493
# [27]	validation_0-rmse:0.85116
# [28]	validation_0-rmse:0.84736
# [29]	validation_0-rmse:0.84357
# [30]	validation_0-rmse:0.83984
# [31]	validation_0-rmse:0.83609
# [32]	validation_0-rmse:0.83235
# [33]	validation_0-rmse:0.82863
# [34]	validation_0-rmse:0.82494
# [35]	validation_0-rmse:0.82126
# [36]	validation_0-rmse:0.81759
# [37]	validation_0-rmse:0.81394
# [38]	validation_0-rmse:0.81031
# [39]	validation_0-rmse:0.80669
# [40]	validation_0-rmse:0.80309
# [41]	validation_0-rmse:0.79951
# [42]	validation_0-rmse:0.79594
# [43]	validation_0-rmse:0.79240
# [44]	validation_0-rmse:0.78887
# [45]	validation_0-rmse:0.78534
# [46]	validation_0-rmse:0.78184
# [47]	validation_0-rmse:0.77839
# [48]	validation_0-rmse:0.77496
# [49]	validation_0-rmse:0.77154
# [50]	validation_0-rmse:0.76810
# [51]	validation_0-rmse:0.76468
# [52]	validation_0-rmse:0.76128
# [53]	validation_0-rmse:0.75788
# [54]	validation_0-rmse:0.75451
# [55]	validation_0-rmse:0.75119
# [56]	validation_0-rmse:0.74784
# [57]	validation_0-rmse:0.74454
# [58]	validation_0-rmse:0.74127
# [59]	validation_0-rmse:0.73796
# [60]	validation_0-rmse:0.73468
# [61]	validation_0-rmse:0.73142
# [62]	validation_0-rmse:0.72820
# [63]	validation_0-rmse:0.72499
# [64]	validation_0-rmse:0.72177
# [65]	validation_0-rmse:0.71860
# [66]	validation_0-rmse:0.71540
# [67]	validation_0-rmse:0.71225
# [68]	validation_0-rmse:0.70908
# [69]	validation_0-rmse:0.70592
# [70]	validation_0-rmse:0.70278
# [71]	validation_0-rmse:0.69966
# [72]	validation_0-rmse:0.69659
# [73]	validation_0-rmse:0.69353
# [74]	validation_0-rmse:0.69048
# [75]	validation_0-rmse:0.68741
# [76]	validation_0-rmse:0.68436
# [77]	validation_0-rmse:0.68135
# [78]	validation_0-rmse:0.67833
# [79]	validation_0-rmse:0.67535
# [80]	validation_0-rmse:0.67241
# [81]	validation_0-rmse:0.66945
# [82]	validation_0-rmse:0.66648
# [83]	validation_0-rmse:0.66352
# [84]	validation_0-rmse:0.66061
# [85]	validation_0-rmse:0.65771
# [86]	validation_0-rmse:0.65479
# [87]	validation_0-rmse:0.65188
# [88]	validation_0-rmse:0.64899
# [89]	validation_0-rmse:0.64611
# [90]	validation_0-rmse:0.64324
# [91]	validation_0-rmse:0.64038
# [92]	validation_0-rmse:0.63757
# [93]	validation_0-rmse:0.63475
# [94]	validation_0-rmse:0.63193
# [95]	validation_0-rmse:0.62913
# [96]	validation_0-rmse:0.62633
# [97]	validation_0-rmse:0.62359
# [98]	validation_0-rmse:0.62083
# [99]	validation_0-rmse:0.61811
# [100]	validation_0-rmse:0.61537
# [101]	validation_0-rmse:0.61265
# [102]	validation_0-rmse:0.60993
# [103]	validation_0-rmse:0.60723
# [104]	validation_0-rmse:0.60455
# [105]	validation_0-rmse:0.60188
# [106]	validation_0-rmse:0.59921
# [107]	validation_0-rmse:0.59656
# [108]	validation_0-rmse:0.59396
# [109]	validation_0-rmse:0.59132
# [110]	validation_0-rmse:0.58870
# [111]	validation_0-rmse:0.58610
# [112]	validation_0-rmse:0.58351
# [113]	validation_0-rmse:0.58096
# [114]	validation_0-rmse:0.57840
# [115]	validation_0-rmse:0.57587
# [116]	validation_0-rmse:0.57332
# [117]	validation_0-rmse:0.57081
# [118]	validation_0-rmse:0.56829
# [119]	validation_0-rmse:0.56578
# [120]	validation_0-rmse:0.56327
# [121]	validation_0-rmse:0.56081
# [122]	validation_0-rmse:0.55834
# [123]	validation_0-rmse:0.55587
# [124]	validation_0-rmse:0.55345
# [125]	validation_0-rmse:0.55100
# [126]	validation_0-rmse:0.54857
# [127]	validation_0-rmse:0.54615
# [128]	validation_0-rmse:0.54374
# [129]	validation_0-rmse:0.54133
# [539]	validation_0-rmse:0.10757
# [540]	validation_0-rmse:0.10725
# [541]	validation_0-rmse:0.10695
# [542]	validation_0-rmse:0.10664
# [543]	validation_0-rmse:0.10633
# [544]	validation_0-rmse:0.10604
# [545]	validation_0-rmse:0.10572
# [546]	validation_0-rmse:0.10542
# [547]	validation_0-rmse:0.10512
# [548]	validation_0-rmse:0.10481
# [549]	validation_0-rmse:0.10451
# [550]	validation_0-rmse:0.10422
# [551]	validation_0-rmse:0.10393
# [552]	validation_0-rmse:0.10364
# [553]	validation_0-rmse:0.10334
# [554]	validation_0-rmse:0.10305
# [555]	validation_0-rmse:0.10277
# [556]	validation_0-rmse:0.10248
# [557]	validation_0-rmse:0.10219
# [558]	validation_0-rmse:0.10191
# [559]	validation_0-rmse:0.10162
# [560]	validation_0-rmse:0.10134
# [561]	validation_0-rmse:0.10107
# [562]	validation_0-rmse:0.10079
# [563]	validation_0-rmse:0.10052
# [564]	validation_0-rmse:0.10024
# [565]	validation_0-rmse:0.09998
# [566]	validation_0-rmse:0.09970
# [567]	validation_0-rmse:0.09943
# [568]	validation_0-rmse:0.09916
# [569]	validation_0-rmse:0.09889
# [570]	validation_0-rmse:0.09864
# [571]	validation_0-rmse:0.09838
# [572]	validation_0-rmse:0.09812
# [573]	validation_0-rmse:0.09786
# [574]	validation_0-rmse:0.09760
# [575]	validation_0-rmse:0.09734
# [576]	validation_0-rmse:0.09708
# [577]	validation_0-rmse:0.09682
# [578]	validation_0-rmse:0.09657
# [579]	validation_0-rmse:0.09632
# [580]	validation_0-rmse:0.09607
# [581]	validation_0-rmse:0.09584
# [582]	validation_0-rmse:0.09560
# [583]	validation_0-rmse:0.09536
# [584]	validation_0-rmse:0.09512
# [585]	validation_0-rmse:0.09487
# [586]	validation_0-rmse:0.09464
# [587]	validation_0-rmse:0.09440
# [588]	validation_0-rmse:0.09416
# [589]	validation_0-rmse:0.09393
# [590]	validation_0-rmse:0.09369
# [591]	validation_0-rmse:0.09346
# [592]	validation_0-rmse:0.09322
# [593]	validation_0-rmse:0.09299
# [594]	validation_0-rmse:0.09276
# [595]	validation_0-rmse:0.09253
# [596]	validation_0-rmse:0.09230
# [597]	validation_0-rmse:0.09208
# [598]	validation_0-rmse:0.09185
# [599]	validation_0-rmse:0.09163
# [600]	validation_0-rmse:0.09143
# [601]	validation_0-rmse:0.09122
# [602]	validation_0-rmse:0.09100
# [603]	validation_0-rmse:0.09080
# [604]	validation_0-rmse:0.09058
# [605]	validation_0-rmse:0.09038
# [606]	validation_0-rmse:0.09017
# [607]	validation_0-rmse:0.08995
# [608]	validation_0-rmse:0.08975
# [609]	validation_0-rmse:0.08955
# [610]	validation_0-rmse:0.08935
# [611]	validation_0-rmse:0.08914
# [612]	validation_0-rmse:0.08893
# [613]	validation_0-rmse:0.08872
# [614]	validation_0-rmse:0.08852
# [615]	validation_0-rmse:0.08833
# [616]	validation_0-rmse:0.08813
# [617]	validation_0-rmse:0.08793
# [618]	validation_0-rmse:0.08774
# [619]	validation_0-rmse:0.08756
# [620]	validation_0-rmse:0.08736
# [621]	validation_0-rmse:0.08716
# [622]	validation_0-rmse:0.08698
# [623]	validation_0-rmse:0.08678
# [624]	validation_0-rmse:0.08660
# [625]	validation_0-rmse:0.08641
# [626]	validation_0-rmse:0.08623
# [627]	validation_0-rmse:0.08605
# [628]	validation_0-rmse:0.08588
# [629]	validation_0-rmse:0.08570
# [630]	validation_0-rmse:0.08553
# [631]	validation_0-rmse:0.08535
# [632]	validation_0-rmse:0.08516
# [633]	validation_0-rmse:0.08498
# [634]	validation_0-rmse:0.08481
# [635]	validation_0-rmse:0.08464
# [636]	validation_0-rmse:0.08446
# [637]	validation_0-rmse:0.08430
# [638]	validation_0-rmse:0.08413
# [639]	validation_0-rmse:0.08397
# [640]	validation_0-rmse:0.08379
# [641]	validation_0-rmse:0.08362
# [642]	validation_0-rmse:0.08345
# [643]	validation_0-rmse:0.08328
# [644]	validation_0-rmse:0.08312
# [645]	validation_0-rmse:0.08295
# [646]	validation_0-rmse:0.08279
# [647]	validation_0-rmse:0.08263
# [648]	validation_0-rmse:0.08246
# [649]	validation_0-rmse:0.08230
# [650]	validation_0-rmse:0.08214
# [651]	validation_0-rmse:0.08198
# [652]	validation_0-rmse:0.08182
# [653]	validation_0-rmse:0.08166
# [654]	validation_0-rmse:0.08151
# [655]	validation_0-rmse:0.08135
# [656]	validation_0-rmse:0.08120
# [657]	validation_0-rmse:0.08104
# [658]	validation_0-rmse:0.08089
# [659]	validation_0-rmse:0.08074
# [660]	validation_0-rmse:0.08059
# [661]	validation_0-rmse:0.08044
# [662]	validation_0-rmse:0.08029
# [663]	validation_0-rmse:0.08015
# [664]	validation_0-rmse:0.08000
# [665]	validation_0-rmse:0.07985
# [666]	validation_0-rmse:0.07971
# [667]	validation_0-rmse:0.07956
# [668]	validation_0-rmse:0.07943
# [669]	validation_0-rmse:0.07929
# [670]	validation_0-rmse:0.07916
# [671]	validation_0-rmse:0.07901
# [672]	validation_0-rmse:0.07887
# [673]	validation_0-rmse:0.07873
# [674]	validation_0-rmse:0.07860
# [675]	validation_0-rmse:0.07846
# [676]	validation_0-rmse:0.07833
# [677]	validation_0-rmse:0.07819
# [678]	validation_0-rmse:0.07806
# [679]	validation_0-rmse:0.07793
# [680]	validation_0-rmse:0.07781
# [681]	validation_0-rmse:0.07769
# [682]	validation_0-rmse:0.07756
# [683]	validation_0-rmse:0.07743
# [684]	validation_0-rmse:0.07730
# [685]	validation_0-rmse:0.07718
# [686]	validation_0-rmse:0.07706
# [687]	validation_0-rmse:0.07693
# [688]	validation_0-rmse:0.07681
# [689]	validation_0-rmse:0.07669
# [690]	validation_0-rmse:0.07656
# [691]	validation_0-rmse:0.07644
# [692]	validation_0-rmse:0.07632
# [693]	validation_0-rmse:0.07620
# [694]	validation_0-rmse:0.07608
# [695]	validation_0-rmse:0.07596
# [696]	validation_0-rmse:0.07584
# [697]	validation_0-rmse:0.07573
# [698]	validation_0-rmse:0.07561
# [699]	validation_0-rmse:0.07551
# [700]	validation_0-rmse:0.07539
# [701]	validation_0-rmse:0.07529
# [702]	validation_0-rmse:0.07517
# [785]	validation_0-rmse:0.06823
# [786]	validation_0-rmse:0.06817
# [787]	validation_0-rmse:0.06811
# [788]	validation_0-rmse:0.06805
# [789]	validation_0-rmse:0.06799
# [790]	validation_0-rmse:0.06794
# [791]	validation_0-rmse:0.06788
# [792]	validation_0-rmse:0.06782
# [793]	validation_0-rmse:0.06776
# [794]	validation_0-rmse:0.06771
# [795]	validation_0-rmse:0.06765
# [796]	validation_0-rmse:0.06759
# [797]	validation_0-rmse:0.06754
# [798]	validation_0-rmse:0.06748
# [799]	validation_0-rmse:0.06743
# [800]	validation_0-rmse:0.06737
# [801]	validation_0-rmse:0.06732
# [802]	validation_0-rmse:0.06727
# [803]	validation_0-rmse:0.06722
# [804]	validation_0-rmse:0.06717
# [805]	validation_0-rmse:0.06712
# [806]	validation_0-rmse:0.06706
# [807]	validation_0-rmse:0.06701
# [808]	validation_0-rmse:0.06696
# [809]	validation_0-rmse:0.06691
# [810]	validation_0-rmse:0.06686
# [811]	validation_0-rmse:0.06681
# [812]	validation_0-rmse:0.06676
# [813]	validation_0-rmse:0.06671
# [814]	validation_0-rmse:0.06666
# [815]	validation_0-rmse:0.06661
# [816]	validation_0-rmse:0.06657
# [817]	validation_0-rmse:0.06652
# [818]	validation_0-rmse:0.06647
# [819]	validation_0-rmse:0.06642
# [820]	validation_0-rmse:0.06637
# [821]	validation_0-rmse:0.06632
# [822]	validation_0-rmse:0.06628
# [823]	validation_0-rmse:0.06623
# [824]	validation_0-rmse:0.06619
# [825]	validation_0-rmse:0.06614
# [826]	validation_0-rmse:0.06610
# [827]	validation_0-rmse:0.06606
# [828]	validation_0-rmse:0.06602
# [829]	validation_0-rmse:0.06597
# [830]	validation_0-rmse:0.06593
# [831]	validation_0-rmse:0.06589
# [832]	validation_0-rmse:0.06584
# [833]	validation_0-rmse:0.06580
# [834]	validation_0-rmse:0.06576
# [835]	validation_0-rmse:0.06572
# [836]	validation_0-rmse:0.06569
# [837]	validation_0-rmse:0.06564
# [838]	validation_0-rmse:0.06560
# [839]	validation_0-rmse:0.06556
# [840]	validation_0-rmse:0.06552
# [841]	validation_0-rmse:0.06549
# [842]	validation_0-rmse:0.06544
# [843]	validation_0-rmse:0.06541
# [844]	validation_0-rmse:0.06537
# [845]	validation_0-rmse:0.06533
# [846]	validation_0-rmse:0.06530
# [847]	validation_0-rmse:0.06526
# [848]	validation_0-rmse:0.06522
# [849]	validation_0-rmse:0.06518
# [850]	validation_0-rmse:0.06514
# [851]	validation_0-rmse:0.06511
# [852]	validation_0-rmse:0.06507
# [853]	validation_0-rmse:0.06503
# [854]	validation_0-rmse:0.06500
# [855]	validation_0-rmse:0.06496
# [856]	validation_0-rmse:0.06493
# [857]	validation_0-rmse:0.06489
# [858]	validation_0-rmse:0.06486
# [859]	validation_0-rmse:0.06482
# [860]	validation_0-rmse:0.06478
# [861]	validation_0-rmse:0.06475
# [862]	validation_0-rmse:0.06471
# [863]	validation_0-rmse:0.06467
# [864]	validation_0-rmse:0.06464
# [865]	validation_0-rmse:0.06461
# [866]	validation_0-rmse:0.06457
# [867]	validation_0-rmse:0.06454
# [868]	validation_0-rmse:0.06450
# [869]	validation_0-rmse:0.06447
# [870]	validation_0-rmse:0.06444
# [871]	validation_0-rmse:0.06441
# [872]	validation_0-rmse:0.06439
# [873]	validation_0-rmse:0.06435
# [874]	validation_0-rmse:0.06432
# [875]	validation_0-rmse:0.06429
# [876]	validation_0-rmse:0.06426
# [877]	validation_0-rmse:0.06423
# [878]	validation_0-rmse:0.06420
# [879]	validation_0-rmse:0.06417
# [880]	validation_0-rmse:0.06414
# [881]	validation_0-rmse:0.06411
# [882]	validation_0-rmse:0.06408
# [883]	validation_0-rmse:0.06405
# [884]	validation_0-rmse:0.06402
# [885]	validation_0-rmse:0.06399
# [886]	validation_0-rmse:0.06396
# [887]	validation_0-rmse:0.06393
# [888]	validation_0-rmse:0.06391
# [889]	validation_0-rmse:0.06388
# [890]	validation_0-rmse:0.06385
# [891]	validation_0-rmse:0.06383
# [892]	validation_0-rmse:0.06380
# [893]	validation_0-rmse:0.06377
# [894]	validation_0-rmse:0.06374
# [895]	validation_0-rmse:0.06371
# [896]	validation_0-rmse:0.06369
# [897]	validation_0-rmse:0.06366
# [898]	validation_0-rmse:0.06363
# [899]	validation_0-rmse:0.06361
# [900]	validation_0-rmse:0.06358
# [901]	validation_0-rmse:0.06355
# [902]	validation_0-rmse:0.06353
# [903]	validation_0-rmse:0.06350
# [904]	validation_0-rmse:0.06348
# [905]	validation_0-rmse:0.06345
# [906]	validation_0-rmse:0.06343
# [907]	validation_0-rmse:0.06340
# [908]	validation_0-rmse:0.06338
# [909]	validation_0-rmse:0.06335
# [910]	validation_0-rmse:0.06333
# [911]	validation_0-rmse:0.06330
# [912]	validation_0-rmse:0.06328
# [913]	validation_0-rmse:0.06325
# [914]	validation_0-rmse:0.06323
# [915]	validation_0-rmse:0.06321
# [916]	validation_0-rmse:0.06319
# [917]	validation_0-rmse:0.06316
# [918]	validation_0-rmse:0.06314
# [919]	validation_0-rmse:0.06312
# [920]	validation_0-rmse:0.06310
# [921]	validation_0-rmse:0.06307
# [922]	validation_0-rmse:0.06305
# [923]	validation_0-rmse:0.06303
# [924]	validation_0-rmse:0.06301
# [925]	validation_0-rmse:0.06299
# [926]	validation_0-rmse:0.06297
# [927]	validation_0-rmse:0.06295
# [928]	validation_0-rmse:0.06293
# [929]	validation_0-rmse:0.06290
# [930]	validation_0-rmse:0.06288
# [931]	validation_0-rmse:0.06287
# [932]	validation_0-rmse:0.06285
# [933]	validation_0-rmse:0.06283
# [934]	validation_0-rmse:0.06281
# [935]	validation_0-rmse:0.06279
# [936]	validation_0-rmse:0.06277
# [937]	validation_0-rmse:0.06274
# [938]	validation_0-rmse:0.06273
# [939]	validation_0-rmse:0.06271
# [940]	validation_0-rmse:0.06269
# [941]	validation_0-rmse:0.06266
# [942]	validation_0-rmse:0.06265
# [943]	validation_0-rmse:0.06263
# [944]	validation_0-rmse:0.06261
# [945]	validation_0-rmse:0.06259
# [946]	validation_0-rmse:0.06257
# [947]	validation_0-rmse:0.06256
# [948]	validation_0-rmse:0.06254
# [949]	validation_0-rmse:0.06252
# [950]	validation_0-rmse:0.06251
# [951]	validation_0-rmse:0.06249
# [952]	validation_0-rmse:0.06247
# [953]	validation_0-rmse:0.06246
# [954]	validation_0-rmse:0.06244
# [955]	validation_0-rmse:0.06242
# [956]	validation_0-rmse:0.06240
# [957]	validation_0-rmse:0.06239
# [958]	validation_0-rmse:0.06237
# [959]	validation_0-rmse:0.06235
# [960]	validation_0-rmse:0.06234
# [961]	validation_0-rmse:0.06232
# [962]	validation_0-rmse:0.06230
# [963]	validation_0-rmse:0.06229
# [964]	validation_0-rmse:0.06227
# [965]	validation_0-rmse:0.06225
# [966]	validation_0-rmse:0.06224
# [967]	validation_0-rmse:0.06222
# [968]	validation_0-rmse:0.06221
# [969]	validation_0-rmse:0.06219
# [970]	validation_0-rmse:0.06217
# [971]	validation_0-rmse:0.06216
# [972]	validation_0-rmse:0.06214
# [973]	validation_0-rmse:0.06213
# [974]	validation_0-rmse:0.06211
# [975]	validation_0-rmse:0.06210
# [976]	validation_0-rmse:0.06208
# [977]	validation_0-rmse:0.06207
# [978]	validation_0-rmse:0.06206
# [979]	validation_0-rmse:0.06204
# [980]	validation_0-rmse:0.06203
# [981]	validation_0-rmse:0.06201
# [982]	validation_0-rmse:0.06200
# [983]	validation_0-rmse:0.06199
# [984]	validation_0-rmse:0.06197
# [985]	validation_0-rmse:0.06196
# [986]	validation_0-rmse:0.06194
# [987]	validation_0-rmse:0.06193
# [988]	validation_0-rmse:0.06192
# [989]	validation_0-rmse:0.06190
# [990]	validation_0-rmse:0.06189
# [991]	validation_0-rmse:0.06188
# [992]	validation_0-rmse:0.06187
# [993]	validation_0-rmse:0.06185
# [994]	validation_0-rmse:0.06184
# [995]	validation_0-rmse:0.06183
# [996]	validation_0-rmse:0.06181
# [997]	validation_0-rmse:0.06180
# [998]	validation_0-rmse:0.06179
# [999]	validation_0-rmse:0.06178
# [1000]	validation_0-rmse:0.06177
# [1001]	validation_0-rmse:0.06175
# [1002]	validation_0-rmse:0.06174
# [1003]	validation_0-rmse:0.06173
# [1004]	validation_0-rmse:0.06172
# [1005]	validation_0-rmse:0.06170
# [1006]	validation_0-rmse:0.06169
# [1007]	validation_0-rmse:0.06168
# [1008]	validation_0-rmse:0.06167
# [1009]	validation_0-rmse:0.06165
# [1010]	validation_0-rmse:0.06164
# [1011]	validation_0-rmse:0.06163
# [1012]	validation_0-rmse:0.06162
# [1013]	validation_0-rmse:0.06161
# [1014]	validation_0-rmse:0.06160
# [1015]	validation_0-rmse:0.06158
# [1016]	validation_0-rmse:0.06157
# [1017]	validation_0-rmse:0.06156
# [1018]	validation_0-rmse:0.06155
# [1019]	validation_0-rmse:0.06154
# [1020]	validation_0-rmse:0.06153
# [1021]	validation_0-rmse:0.06152
# [1022]	validation_0-rmse:0.06151
# [1023]	validation_0-rmse:0.06150
# [1024]	validation_0-rmse:0.06149
# [1025]	validation_0-rmse:0.06148
# [1026]	validation_0-rmse:0.06147
# [1027]	validation_0-rmse:0.06146
# [1028]	validation_0-rmse:0.06145
# [1638]	validation_0-rmse:0.06004
# [1639]	validation_0-rmse:0.06004
# [1640]	validation_0-rmse:0.06004
# [1641]	validation_0-rmse:0.06004
# [1642]	validation_0-rmse:0.06004
# [1643]	validation_0-rmse:0.06004
# [1644]	validation_0-rmse:0.06004
# [1645]	validation_0-rmse:0.06004
# [1646]	validation_0-rmse:0.06004
# [1647]	validation_0-rmse:0.06004
# [1648]	validation_0-rmse:0.06004
# [1649]	validation_0-rmse:0.06004
# [1650]	validation_0-rmse:0.06004
# [1651]	validation_0-rmse:0.06004
# [1652]	validation_0-rmse:0.06004
# [1653]	validation_0-rmse:0.06004
# [1654]	validation_0-rmse:0.06004
# [1655]	validation_0-rmse:0.06004
# [1656]	validation_0-rmse:0.06004
# [1657]	validation_0-rmse:0.06004
# [1658]	validation_0-rmse:0.06004
# [1659]	validation_0-rmse:0.06004
# [1660]	validation_0-rmse:0.06004
# [1661]	validation_0-rmse:0.06004
# [1662]	validation_0-rmse:0.06004
# [1663]	validation_0-rmse:0.06004
# [1664]	validation_0-rmse:0.06004
# [1665]	validation_0-rmse:0.06004
# [1666]	validation_0-rmse:0.06004
# [1667]	validation_0-rmse:0.06004
# [1668]	validation_0-rmse:0.06004
# [1669]	validation_0-rmse:0.06004
# [1670]	validation_0-rmse:0.06004
# [1671]	validation_0-rmse:0.06004
# [1672]	validation_0-rmse:0.06004
# [1673]	validation_0-rmse:0.06004
# [1674]	validation_0-rmse:0.06004
# [1675]	validation_0-rmse:0.06003
# [1676]	validation_0-rmse:0.06003
# [1677]	validation_0-rmse:0.06003
# [1678]	validation_0-rmse:0.06003
# [1679]	validation_0-rmse:0.06003
# [1680]	validation_0-rmse:0.06003
# [1681]	validation_0-rmse:0.06003
# [1682]	validation_0-rmse:0.06003
# [1683]	validation_0-rmse:0.06003
# [1684]	validation_0-rmse:0.06003
# [1685]	validation_0-rmse:0.06003
# [1686]	validation_0-rmse:0.06003
# [1687]	validation_0-rmse:0.06003
# [1688]	validation_0-rmse:0.06003
# [1689]	validation_0-rmse:0.06003
# [1690]	validation_0-rmse:0.06003
# [1691]	validation_0-rmse:0.06003
# [1692]	validation_0-rmse:0.06003
# [1693]	validation_0-rmse:0.06003
# [1694]	validation_0-rmse:0.06003
# [1695]	validation_0-rmse:0.06003
# [1696]	validation_0-rmse:0.06003
# [1697]	validation_0-rmse:0.06003
# [1698]	validation_0-rmse:0.06003
# [1699]	validation_0-rmse:0.06003
# [1700]	validation_0-rmse:0.06003
# [1701]	validation_0-rmse:0.06003
# [1702]	validation_0-rmse:0.06003
# [1703]	validation_0-rmse:0.06003
# [1704]	validation_0-rmse:0.06003
# [1705]	validation_0-rmse:0.06003
# [1706]	validation_0-rmse:0.06003
# [1707]	validation_0-rmse:0.06003
# [1708]	validation_0-rmse:0.06003
# [1709]	validation_0-rmse:0.06003
# [1710]	validation_0-rmse:0.06003
# [1711]	validation_0-rmse:0.06003
# [1712]	validation_0-rmse:0.06003
# [1713]	validation_0-rmse:0.06003
# [1714]	validation_0-rmse:0.06003
# [1715]	validation_0-rmse:0.06003
# [1716]	validation_0-rmse:0.06003
# [1717]	validation_0-rmse:0.06003
# [1718]	validation_0-rmse:0.06002
# [1719]	validation_0-rmse:0.06002
# [1720]	validation_0-rmse:0.06002
# [1721]	validation_0-rmse:0.06002
# [1722]	validation_0-rmse:0.06002
# [1723]	validation_0-rmse:0.06002
# [1724]	validation_0-rmse:0.06002
# [1725]	validation_0-rmse:0.06002
# [1726]	validation_0-rmse:0.06002
# [1727]	validation_0-rmse:0.06002
# [1728]	validation_0-rmse:0.06002
# [1729]	validation_0-rmse:0.06002
# [1730]	validation_0-rmse:0.06002
# [1731]	validation_0-rmse:0.06002
# [1732]	validation_0-rmse:0.06002
# [1733]	validation_0-rmse:0.06002
# [1734]	validation_0-rmse:0.06002
# [1735]	validation_0-rmse:0.06002
# [1736]	validation_0-rmse:0.06002
# [1737]	validation_0-rmse:0.06002
# [1738]	validation_0-rmse:0.06002
# [1739]	validation_0-rmse:0.06002
# [1740]	validation_0-rmse:0.06002
# [1741]	validation_0-rmse:0.06002
# [1742]	validation_0-rmse:0.06002
# [1743]	validation_0-rmse:0.06002
# [1744]	validation_0-rmse:0.06002
# [1745]	validation_0-rmse:0.06002
# [1746]	validation_0-rmse:0.06002
# [1747]	validation_0-rmse:0.06002
# [1748]	validation_0-rmse:0.06002
# [1749]	validation_0-rmse:0.06002
# [1750]	validation_0-rmse:0.06002
# [1751]	validation_0-rmse:0.06002
# [1752]	validation_0-rmse:0.06002
# [1753]	validation_0-rmse:0.06002
# [1754]	validation_0-rmse:0.06002
# [1755]	validation_0-rmse:0.06002
# [1756]	validation_0-rmse:0.06002
# [1757]	validation_0-rmse:0.06002
# [1758]	validation_0-rmse:0.06002
# [1759]	validation_0-rmse:0.06002
# [1760]	validation_0-rmse:0.06002
# [1761]	validation_0-rmse:0.06002
# [1762]	validation_0-rmse:0.06002
# [1763]	validation_0-rmse:0.06002
# [1764]	validation_0-rmse:0.06002
# [1765]	validation_0-rmse:0.06002
# [1766]	validation_0-rmse:0.06002
# [1767]	validation_0-rmse:0.06002
# [1768]	validation_0-rmse:0.06002
# [1769]	validation_0-rmse:0.06002
# [1770]	validation_0-rmse:0.06002
# [1771]	validation_0-rmse:0.06002
# [1772]	validation_0-rmse:0.06002
# [1773]	validation_0-rmse:0.06002
# [1774]	validation_0-rmse:0.06002
# [1775]	validation_0-rmse:0.06002
# [1776]	validation_0-rmse:0.06002
# [1777]	validation_0-rmse:0.06002
# [1778]	validation_0-rmse:0.06002
# [1779]	validation_0-rmse:0.06002
# [1780]	validation_0-rmse:0.06002
# [1781]	validation_0-rmse:0.06002
# [1782]	validation_0-rmse:0.06002
# [1783]	validation_0-rmse:0.06001
# [1784]	validation_0-rmse:0.06001
# [1785]	validation_0-rmse:0.06001
# [1786]	validation_0-rmse:0.06001
# [1787]	validation_0-rmse:0.06001
# [1788]	validation_0-rmse:0.06001
# [1789]	validation_0-rmse:0.06001
# [1790]	validation_0-rmse:0.06001
# [1791]	validation_0-rmse:0.06001
# [1792]	validation_0-rmse:0.06001
# [1793]	validation_0-rmse:0.06001
# [1794]	validation_0-rmse:0.06001
# [1795]	validation_0-rmse:0.06001
# [1796]	validation_0-rmse:0.06001
# [1797]	validation_0-rmse:0.06001
# [1798]	validation_0-rmse:0.06001
# [1799]	validation_0-rmse:0.06001
# [1800]	validation_0-rmse:0.06001
# [1801]	validation_0-rmse:0.06001
# [1802]	validation_0-rmse:0.06001
# [1803]	validation_0-rmse:0.06001
# [1804]	validation_0-rmse:0.06001
# [1805]	validation_0-rmse:0.06001
# [1806]	validation_0-rmse:0.06001
# [1807]	validation_0-rmse:0.06001
# [1808]	validation_0-rmse:0.06001
# [1809]	validation_0-rmse:0.06001
# [1810]	validation_0-rmse:0.06001
# [1811]	validation_0-rmse:0.06001
# [1812]	validation_0-rmse:0.06001
# [1813]	validation_0-rmse:0.06001
# [1814]	validation_0-rmse:0.06001
# [1815]	validation_0-rmse:0.06001
# [1816]	validation_0-rmse:0.06001
# [1817]	validation_0-rmse:0.06001
# [1818]	validation_0-rmse:0.06001
# [1819]	validation_0-rmse:0.06001
# [1820]	validation_0-rmse:0.06001
# [1821]	validation_0-rmse:0.06001
# [1822]	validation_0-rmse:0.06001
# [1823]	validation_0-rmse:0.06001
# [1824]	validation_0-rmse:0.06001
# [1825]	validation_0-rmse:0.06001
# [1826]	validation_0-rmse:0.06001
# [1827]	validation_0-rmse:0.06001
# [1828]	validation_0-rmse:0.06001
# [1829]	validation_0-rmse:0.06001
# [1830]	validation_0-rmse:0.06001
# [1831]	validation_0-rmse:0.06001
# [1832]	validation_0-rmse:0.06001
# [1833]	validation_0-rmse:0.06000
# [1834]	validation_0-rmse:0.06000
# [1835]	validation_0-rmse:0.06001
# [1836]	validation_0-rmse:0.06000
# [1837]	validation_0-rmse:0.06000
# [1838]	validation_0-rmse:0.06000
# [1839]	validation_0-rmse:0.06000
# [1840]	validation_0-rmse:0.06000
# [1841]	validation_0-rmse:0.06001
# [1842]	validation_0-rmse:0.06000
# [1843]	validation_0-rmse:0.06000
# [1844]	validation_0-rmse:0.06000
# [1845]	validation_0-rmse:0.06000
# [1846]	validation_0-rmse:0.06000
# [1847]	validation_0-rmse:0.06000
# [1848]	validation_0-rmse:0.06000
# [1849]	validation_0-rmse:0.06000
# [1850]	validation_0-rmse:0.06000
# [1851]	validation_0-rmse:0.06000
# [1852]	validation_0-rmse:0.06000
# [1853]	validation_0-rmse:0.06000
# [1854]	validation_0-rmse:0.06000
# [1855]	validation_0-rmse:0.06000
# [1856]	validation_0-rmse:0.06000
# [1857]	validation_0-rmse:0.06000
# [1858]	validation_0-rmse:0.06000
# [1859]	validation_0-rmse:0.06000
# [1860]	validation_0-rmse:0.06000
# [1861]	validation_0-rmse:0.06000
# [1862]	validation_0-rmse:0.06000
# [1863]	validation_0-rmse:0.06000
# [1864]	validation_0-rmse:0.06000
# [1865]	validation_0-rmse:0.06000
# [1866]	validation_0-rmse:0.06000
# [1867]	validation_0-rmse:0.06000
# [1868]	validation_0-rmse:0.06000
# [1869]	validation_0-rmse:0.06000
# [1870]	validation_0-rmse:0.06000
# [1949]	validation_0-rmse:0.05999
# [1950]	validation_0-rmse:0.05999
# [1951]	validation_0-rmse:0.05999
# [1952]	validation_0-rmse:0.05999
# [1953]	validation_0-rmse:0.05999
# [1954]	validation_0-rmse:0.05999
# [1955]	validation_0-rmse:0.05999
# [1956]	validation_0-rmse:0.05999
# [1957]	validation_0-rmse:0.05999
# [1958]	validation_0-rmse:0.05999
# [1959]	validation_0-rmse:0.05999
# [1960]	validation_0-rmse:0.05999
# [1961]	validation_0-rmse:0.05999
# [1962]	validation_0-rmse:0.05999
# [1963]	validation_0-rmse:0.05999
# [1964]	validation_0-rmse:0.05999
# [1965]	validation_0-rmse:0.05999
# [1966]	validation_0-rmse:0.05999
# [1967]	validation_0-rmse:0.05999
# [1968]	validation_0-rmse:0.05999
# [1969]	validation_0-rmse:0.05999
# [1970]	validation_0-rmse:0.05999
# [1971]	validation_0-rmse:0.05999
# [1972]	validation_0-rmse:0.05999
# [1973]	validation_0-rmse:0.05999
# [1974]	validation_0-rmse:0.05999
# [1975]	validation_0-rmse:0.05999
# [1976]	validation_0-rmse:0.05999
# [1977]	validation_0-rmse:0.05999
# [1978]	validation_0-rmse:0.05999
# [1979]	validation_0-rmse:0.05999
# [1980]	validation_0-rmse:0.05999
# [1981]	validation_0-rmse:0.05999
# [1982]	validation_0-rmse:0.05999
# [1983]	validation_0-rmse:0.05999
# [1984]	validation_0-rmse:0.05999
# [1985]	validation_0-rmse:0.05999
# [1986]	validation_0-rmse:0.05999
# [1987]	validation_0-rmse:0.05999
# [1988]	validation_0-rmse:0.05999
# [1989]	validation_0-rmse:0.05999
# [1990]	validation_0-rmse:0.05999
# [1991]	validation_0-rmse:0.05999
# [1992]	validation_0-rmse:0.05999
# [1993]	validation_0-rmse:0.05999
# [1994]	validation_0-rmse:0.05999
# [1995]	validation_0-rmse:0.05999
# [1996]	validation_0-rmse:0.05999
# [1997]	validation_0-rmse:0.05999
# [1998]	validation_0-rmse:0.05999
# [1999]	validation_0-rmse:0.05999
# Numero ottimale di boosting rounds: 1999
# Hold-out → RMSE: 3.6272, RMSLE: 0.0600
#
# Addestramento modelli CV ensemble...
#
# Training fold 1/5
# Fold 1 RMSLE: 0.0593
#
# Training fold 2/5
# Fold 2 RMSLE: 0.0604
#
# Training fold 3/5
# Fold 3 RMSLE: 0.0595
#
# Training fold 4/5
# Fold 4 RMSLE: 0.0600
#
# Training fold 5/5
# Fold 5 RMSLE: 0.0595
#
# Out-of-fold RMSLE: 1.3615
#
# Top 10 feature importances:
#              Feature  Importance
# 0  Heart_Beats_Total    0.536454
# 1           Duration    0.373274
# 2        HBT_per_BSA    0.051473
# 3     BMI_x_Duration    0.024074
# 4                Age    0.004713
# 5                Sex    0.003671
# 6         Heart_Rate    0.003215
# 7             Weight    0.000843
# 8         Delta_Temp    0.000609
# 9          Body_Temp    0.000567
#
# Preview delle predizioni:
#        id  Pred_Calories
# 0  750000      27.220551
# 1  750001     107.799164
# 2  750002      87.642426
# 3  750003     126.319870
# 4  750004      75.847260
#
# Creato file pronto per il submit con ensemble CV!
