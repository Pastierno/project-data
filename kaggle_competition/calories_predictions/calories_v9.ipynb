# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import PowerTransformer, StandardScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_squared_log_error, make_scorer
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from functools import partial

# 1. Caricamento dati
df_train = pd.read_csv('/content/drive/MyDrive/data_calories/train.csv')
df_test  = pd.read_csv('/content/drive/MyDrive/data_calories/test.csv')

# 2. Feature engineering avanzato
def make_features(df):
    df = df.copy()
    df['Sex']               = df['Sex'].map({'male': 0, 'female': 1})
    df['BMI']               = df['Weight'] / (df['Height'] / 100) ** 2
    df['BSA']               = 0.007184 * df['Weight']**0.425 * df['Height']**0.725
    #df['Delta_Temp']        = df['Body_Temp'] - 37.0
    df['HR_per_kg']         = df['Heart_Rate'] / df['Weight']
    df['Heart_Beats_Total'] = df['Heart_Rate'] * df['Duration']
    # Interazioni aggiuntive
    df['BMI_x_Duration']    = df['BMI'] * df['Duration']
    df['HBT_per_BSA']       = df['Heart_Beats_Total'] / df['BSA']
    df['BMI_squared']       = df['BMI'] ** 2
    return df

train_fe = make_features(df_train)
test_fe  = make_features(df_test)

# 3. EDA rapida per verificare le feature (opzionale, commentato per esecuzione)
"""
plt.figure(figsize=(12, 8))
corr = train_fe.drop('id', axis=1).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matrice di Correlazione')
plt.tight_layout()
plt.show()
"""

# 4. Definizione di X e y
X = train_fe.drop(columns=['id', 'Calories'])
y = train_fe['Calories']
X_test_raw = test_fe.drop(columns=['id'])

# 5. Identificazione delle feature asimmetriche
skew_thresh  = 0.40
skewness     = X.skew().abs()
skewed_feats = skewness[skewness > skew_thresh].index.tolist()
pos_feats    = [f for f in skewed_feats if (X[f] > 0).all()]
nonpos_feats = [f for f in skewed_feats if f not in pos_feats]

# 6. Preprocessing
# 6.1 Fit del PowerTransformer sui nonpos_feats
pt = None
if nonpos_feats:
    pt = PowerTransformer(method='yeo-johnson', standardize=False)
    pt.fit(X[nonpos_feats])

# 6.2 Trasformazione log1p per pos_feats e PowerTransformer per nonpos_feats
X_p = X.copy()
for f in pos_feats:
    X_p[f] = np.log1p(X_p[f])
if nonpos_feats:
    X_p[nonpos_feats] = pt.transform(X_p[nonpos_feats])

# 6.3 Robust Scaling
scaler = RobustScaler()
scaler.fit(X_p)
X_proc = pd.DataFrame(scaler.transform(X_p), columns=X.columns, index=X.index)

# 6.4 Preprocessing del test set
X_test_p = X_test_raw.copy()
for f in pos_feats:
    X_test_p[f] = np.log1p(X_test_p[f])
if nonpos_feats:
    X_test_p[nonpos_feats] = pt.transform(X_test_p[nonpos_feats])
X_test_proc = pd.DataFrame(scaler.transform(X_test_p), columns=X_test_p.columns)

# 7. Log-transform del target
y_log = np.log1p(y)

# 8. Definizione dello split per hold-out (10%)
X_train_main, X_hold, y_train_main, y_hold = train_test_split(
    X_proc, y_log, test_size=0.1, random_state=42
)

# 9. Iperparametri ottimali da Optuna (trial 17)
best_params = {
    'learning_rate':    0.004523596335091698,
    'max_depth':        9,
    'subsample':        0.9708888609967907,
    'colsample_bytree': 0.7684560546712256,
    'min_child_weight': 5,
    'reg_alpha':        2.9753791923207157e-05,
    'reg_lambda':       2.986233138083534
}

# 10. Definizione metrica custom RMSLE per cross-validation
def rmsle_scorer(y_true, y_pred):
    y_true_exp = np.expm1(y_true)
    y_pred_exp = np.expm1(y_pred)
    return np.sqrt(mean_squared_log_error(y_true_exp, y_pred_exp))

custom_rmsle_scorer = make_scorer(rmsle_scorer, greater_is_better=False)

# 11. Cross-validation con KFold
n_folds = 10
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)

# Inizializzazione del modello base per CV
cv_model = XGBRegressor(
    objective='reg:squarederror',
    eval_metric='rmse',
    random_state=42,
    **best_params
)

# Esecuzione CV sul training set principale (escludendo hold-out)
cv_results = cross_val_score(
    cv_model,
    X_train_main,
    y_train_main,
    cv=kf,
    scoring=custom_rmsle_scorer,
    n_jobs=-1,
    verbose=1
)

# Stampa risultati CV
cv_rmsle_scores = -cv_results  # Converto da negative a positive scores
print(f"Cross-Validation RMSLE Scores: {cv_rmsle_scores}")
print(f"Mean CV RMSLE: {cv_rmsle_scores.mean():.4f}, Std: {cv_rmsle_scores.std():.4f}")

# 12. Allenamento con early stopping su hold-out
model_es = XGBRegressor(
    objective='reg:squarederror',
    eval_metric='rmse',
    random_state=42,
    n_estimators=2000,
    early_stopping_rounds=50,
    verbosity=1,
    **best_params
)
model_es.fit(
    X_train_main, y_train_main,
    eval_set=[(X_hold, y_hold)],
    verbose=True
)

print(f"Numero ottimale di boosting rounds: {model_es.best_iteration}")

# 13. Valutazione su hold-out
y_pred_log = model_es.predict(X_hold)
y_pred     = np.expm1(y_pred_log)
y_true     = np.expm1(y_hold)
rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
rmsle = np.sqrt(mean_squared_log_error(y_true, y_pred))
print(f"Hold-out → RMSE: {rmse:.4f}, RMSLE: {rmsle:.4f}")

# 14. Re-fit su tutto il training set con CV ensemble
final_models = []
fold_predictions = []

print("\nAddestramento modelli CV ensemble...")
for fold, (train_idx, val_idx) in enumerate(kf.split(X_proc)):
    print(f"\nTraining fold {fold+1}/{n_folds}")
    X_train_fold, X_val_fold = X_proc.iloc[train_idx], X_proc.iloc[val_idx]
    y_train_fold, y_val_fold = y_log.iloc[train_idx], y_log.iloc[val_idx]

    # Modello fold con early stopping interno
    fold_model = XGBRegressor(
        objective='reg:squarederror',
        eval_metric='rmse',
        random_state=42,
        n_estimators=model_es.best_iteration,  # Numero di round ottimale trovato precedentemente
        verbosity=1,
        **best_params
    )

    # Fit con early stopping su validation set del fold
    fold_model.fit(
        X_train_fold, y_train_fold,
        eval_set=[(X_val_fold, y_val_fold)],
        verbose=False
    )

    # Validazione fold
    fold_preds = fold_model.predict(X_val_fold)
    fold_preds_exp = np.expm1(fold_preds)
    fold_true_exp = np.expm1(y_val_fold)
    fold_rmsle = np.sqrt(mean_squared_log_error(fold_true_exp, fold_preds_exp))
    print(f"Fold {fold+1} RMSLE: {fold_rmsle:.4f}")

    # Salvare previsioni e modello
    fold_predictions.append((val_idx, fold_preds))
    final_models.append(fold_model)

# 15. Validazione OOF (Out-of-fold)
oof_true_indices = np.concatenate([idx for idx, _ in fold_predictions])
oof_preds = np.concatenate([pred for _, pred in sorted(fold_predictions, key=lambda x: x[0][0])])
oof_preds_exp = np.expm1(oof_preds)
oof_true_exp = np.expm1(y_log.iloc[oof_true_indices])

oof_rmsle = np.sqrt(mean_squared_log_error(oof_true_exp, oof_preds_exp))
print(f"\nOut-of-fold RMSLE: {oof_rmsle:.4f}")

# 16. Previsioni finali (media degli ensemble models)
test_preds = []
for model in final_models:
    test_pred = model.predict(X_test_proc)
    test_preds.append(test_pred)

# Media delle previsioni log-scale e trasformazione inversa
y_test_log_ensemble = np.mean(test_preds, axis=0)
y_test_ensemble = np.expm1(y_test_log_ensemble)

# 17. Feature importance media
importance_df = pd.DataFrame()
importance_df['Feature'] = X.columns
importance_df['Importance'] = np.mean([model.feature_importances_ for model in final_models], axis=0)
importance_df = importance_df.sort_values('Importance', ascending=False).reset_index(drop=True)

print("\nTop 10 feature importances:")
print(importance_df.head(10))

# 18. Creazione submission
df_test['Pred_Calories'] = y_test_ensemble
df_test[['id', 'Pred_Calories']].to_csv('submission.csv', index=False)
print("\nPreview delle predizioni:")
print(df_test[['id', 'Pred_Calories']].head())

submission = pd.read_csv('/content/drive/MyDrive/data_calories/sample_submission.csv')
submission['Calories'] = df_test['Pred_Calories']
submission.to_csv('/content/drive/MyDrive/data_calories/submission_cv_ensemble.csv', index=False)
print("\nCreato file pronto per il submit con ensemble CV!")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.4min finished
# Cross-Validation RMSLE Scores: [0.61804133 0.61533677 0.61718857 0.61653014 0.62105008 0.61675175
#  0.61506709 0.6143131  0.61890586 0.61661916]
# Mean CV RMSLE: 0.6170, Std: 0.0019
# [0]	validation_0-rmse:0.96014
# [1]	validation_0-rmse:0.95584
# [2]	validation_0-rmse:0.95161
# [3]	validation_0-rmse:0.94735
# [4]	validation_0-rmse:0.94311
# [5]	validation_0-rmse:0.93893
# [6]	validation_0-rmse:0.93478
# [7]	validation_0-rmse:0.93064
# [8]	validation_0-rmse:0.92648
# [9]	validation_0-rmse:0.92234
# [10]	validation_0-rmse:0.91822
# [11]	validation_0-rmse:0.91411
# [12]	validation_0-rmse:0.91002
# [13]	validation_0-rmse:0.90595
# [14]	validation_0-rmse:0.90194
# [15]	validation_0-rmse:0.89795
# [16]	validation_0-rmse:0.89394
# [17]	validation_0-rmse:0.88995
# [18]	validation_0-rmse:0.88597
# [19]	validation_0-rmse:0.88203
# [20]	validation_0-rmse:0.87808
# [21]	validation_0-rmse:0.87420
# [22]	validation_0-rmse:0.87030
# [23]	validation_0-rmse:0.86642
# [24]	validation_0-rmse:0.86259
# [25]	validation_0-rmse:0.85874
# [26]	validation_0-rmse:0.85490
# [27]	validation_0-rmse:0.85109
# [28]	validation_0-rmse:0.84729
# [29]	validation_0-rmse:0.84355
# [30]	validation_0-rmse:0.83982
# [31]	validation_0-rmse:0.83607
# [32]	validation_0-rmse:0.83234
# [33]	validation_0-rmse:0.82862
# [34]	validation_0-rmse:0.82493
# [35]	validation_0-rmse:0.82125
# [36]	validation_0-rmse:0.81759
# [37]	validation_0-rmse:0.81395
# [38]	validation_0-rmse:0.81036
# [39]	validation_0-rmse:0.80674
# [40]	validation_0-rmse:0.80318
# [41]	validation_0-rmse:0.79959
# [42]	validation_0-rmse:0.79606
# [43]	validation_0-rmse:0.79252
# [44]	validation_0-rmse:0.78898
# [45]	validation_0-rmse:0.78547
# [46]	validation_0-rmse:0.78196
# [47]	validation_0-rmse:0.77848
# [48]	validation_0-rmse:0.77505
# [49]	validation_0-rmse:0.77160
# [50]	validation_0-rmse:0.76816
# [51]	validation_0-rmse:0.76473
# [52]	validation_0-rmse:0.76133
# [53]	validation_0-rmse:0.75794
# [54]	validation_0-rmse:0.75460
# [55]	validation_0-rmse:0.75127
# [56]	validation_0-rmse:0.74796
# [57]	validation_0-rmse:0.74463
# [58]	validation_0-rmse:0.74135
# [59]	validation_0-rmse:0.73809
# [60]	validation_0-rmse:0.73480
# [61]	validation_0-rmse:0.73157
# [62]	validation_0-rmse:0.72831
# [63]	validation_0-rmse:0.72511
# [64]	validation_0-rmse:0.72188
# [65]	validation_0-rmse:0.71867
# [66]	validation_0-rmse:0.71552
# [67]	validation_0-rmse:0.71233
# [68]	validation_0-rmse:0.70917
# [69]	validation_0-rmse:0.70601
# [70]	validation_0-rmse:0.70291
# [71]	validation_0-rmse:0.69982
# [72]	validation_0-rmse:0.69675
# [73]	validation_0-rmse:0.69365
# [74]	validation_0-rmse:0.69057
# [75]	validation_0-rmse:0.68749
# [76]	validation_0-rmse:0.68448
# [77]	validation_0-rmse:0.68147
# [78]	validation_0-rmse:0.67845
# [79]	validation_0-rmse:0.67543
# [80]	validation_0-rmse:0.67243
# [81]	validation_0-rmse:0.66948
# [82]	validation_0-rmse:0.66650
# [83]	validation_0-rmse:0.66357
# [84]	validation_0-rmse:0.66062
# [85]	validation_0-rmse:0.65773
# [86]	validation_0-rmse:0.65480
# [87]	validation_0-rmse:0.65194
# [88]	validation_0-rmse:0.64904
# [89]	validation_0-rmse:0.64616
# [90]	validation_0-rmse:0.64333
# [91]	validation_0-rmse:0.64047
# [92]	validation_0-rmse:0.63763
# [93]	validation_0-rmse:0.63480
# [94]	validation_0-rmse:0.63198
# [95]	validation_0-rmse:0.62918
# [96]	validation_0-rmse:0.62639
# [97]	validation_0-rmse:0.62361
# [98]	validation_0-rmse:0.62084
# [99]	validation_0-rmse:0.61808
# [100]	validation_0-rmse:0.61535
# [101]	validation_0-rmse:0.61262
# [102]	validation_0-rmse:0.60995
# [103]	validation_0-rmse:0.60724
# [104]	validation_0-rmse:0.60458
# [105]	validation_0-rmse:0.60194
# [106]	validation_0-rmse:0.59928
# [107]	validation_0-rmse:0.59666
# [108]	validation_0-rmse:0.59402
# [109]	validation_0-rmse:0.59142
# [110]	validation_0-rmse:0.58881
# [111]	validation_0-rmse:0.58624
# [112]	validation_0-rmse:0.58365
# [113]	validation_0-rmse:0.58106
# [114]	validation_0-rmse:0.57850
# [115]	validation_0-rmse:0.57594
# [116]	validation_0-rmse:0.57343
# [117]	validation_0-rmse:0.57089
# [118]	validation_0-rmse:0.56840
# [119]	validation_0-rmse:0.56592
# [120]	validation_0-rmse:0.56342
# [121]	validation_0-rmse:0.56096
# [122]	validation_0-rmse:0.55848
# [123]	validation_0-rmse:0.55604
# [124]	validation_0-rmse:0.55359
# [125]	validation_0-rmse:0.55114
# [126]	validation_0-rmse:0.54873
# [127]	validation_0-rmse:0.54634
# [375]	validation_0-rmse:0.19132
# [376]	validation_0-rmse:0.19056
# [377]	validation_0-rmse:0.18983
# [378]	validation_0-rmse:0.18909
# [379]	validation_0-rmse:0.18837
# [380]	validation_0-rmse:0.18762
# [381]	validation_0-rmse:0.18691
# [382]	validation_0-rmse:0.18617
# [383]	validation_0-rmse:0.18546
# [384]	validation_0-rmse:0.18473
# [385]	validation_0-rmse:0.18401
# [386]	validation_0-rmse:0.18328
# [387]	validation_0-rmse:0.18256
# [388]	validation_0-rmse:0.18187
# [389]	validation_0-rmse:0.18115
# [390]	validation_0-rmse:0.18045
# [391]	validation_0-rmse:0.17977
# [392]	validation_0-rmse:0.17906
# [393]	validation_0-rmse:0.17837
# [394]	validation_0-rmse:0.17770
# [395]	validation_0-rmse:0.17701
# [396]	validation_0-rmse:0.17635
# [397]	validation_0-rmse:0.17567
# [398]	validation_0-rmse:0.17499
# [399]	validation_0-rmse:0.17434
# [400]	validation_0-rmse:0.17367
# [401]	validation_0-rmse:0.17299
# [402]	validation_0-rmse:0.17233
# [403]	validation_0-rmse:0.17169
# [404]	validation_0-rmse:0.17102
# [405]	validation_0-rmse:0.17037
# [406]	validation_0-rmse:0.16974
# [407]	validation_0-rmse:0.16909
# [408]	validation_0-rmse:0.16844
# [409]	validation_0-rmse:0.16779
# [410]	validation_0-rmse:0.16716
# [411]	validation_0-rmse:0.16652
# [412]	validation_0-rmse:0.16591
# [413]	validation_0-rmse:0.16527
# [414]	validation_0-rmse:0.16464
# [415]	validation_0-rmse:0.16404
# [416]	validation_0-rmse:0.16342
# [417]	validation_0-rmse:0.16280
# [418]	validation_0-rmse:0.16220
# [419]	validation_0-rmse:0.16159
# [420]	validation_0-rmse:0.16098
# [421]	validation_0-rmse:0.16038
# [422]	validation_0-rmse:0.15978
# [423]	validation_0-rmse:0.15918
# [424]	validation_0-rmse:0.15858
# [425]	validation_0-rmse:0.15801
# [426]	validation_0-rmse:0.15743
# [427]	validation_0-rmse:0.15686
# [428]	validation_0-rmse:0.15630
# [429]	validation_0-rmse:0.15572
# [430]	validation_0-rmse:0.15513
# [431]	validation_0-rmse:0.15456
# [432]	validation_0-rmse:0.15399
# [433]	validation_0-rmse:0.15341
# [434]	validation_0-rmse:0.15285
# [435]	validation_0-rmse:0.15228
# [436]	validation_0-rmse:0.15172
# [437]	validation_0-rmse:0.15116
# [438]	validation_0-rmse:0.15061
# [439]	validation_0-rmse:0.15006
# [440]	validation_0-rmse:0.14951
# [441]	validation_0-rmse:0.14896
# [442]	validation_0-rmse:0.14844
# [443]	validation_0-rmse:0.14789
# [444]	validation_0-rmse:0.14738
# [445]	validation_0-rmse:0.14684
# [446]	validation_0-rmse:0.14633
# [447]	validation_0-rmse:0.14580
# [448]	validation_0-rmse:0.14527
# [449]	validation_0-rmse:0.14474
# [450]	validation_0-rmse:0.14422
# [451]	validation_0-rmse:0.14371
# [452]	validation_0-rmse:0.14319
# [453]	validation_0-rmse:0.14268
# [454]	validation_0-rmse:0.14219
# [455]	validation_0-rmse:0.14168
# [456]	validation_0-rmse:0.14119
# [457]	validation_0-rmse:0.14068
# [458]	validation_0-rmse:0.14020
# [459]	validation_0-rmse:0.13971
# [460]	validation_0-rmse:0.13921
# [461]	validation_0-rmse:0.13872
# [462]	validation_0-rmse:0.13823
# [463]	validation_0-rmse:0.13777
# [464]	validation_0-rmse:0.13729
# [465]	validation_0-rmse:0.13681
# [466]	validation_0-rmse:0.13635
# [467]	validation_0-rmse:0.13588
# [468]	validation_0-rmse:0.13540
# [469]	validation_0-rmse:0.13493
# [470]	validation_0-rmse:0.13448
# [471]	validation_0-rmse:0.13401
# [472]	validation_0-rmse:0.13354
# [473]	validation_0-rmse:0.13309
# [474]	validation_0-rmse:0.13263
# [475]	validation_0-rmse:0.13216
# [476]	validation_0-rmse:0.13172
# [477]	validation_0-rmse:0.13128
# [478]	validation_0-rmse:0.13084
# [479]	validation_0-rmse:0.13040
# [480]	validation_0-rmse:0.12995
# [481]	validation_0-rmse:0.12950
# [482]	validation_0-rmse:0.12908
# [483]	validation_0-rmse:0.12864
# [484]	validation_0-rmse:0.12820
# [485]	validation_0-rmse:0.12779
# [486]	validation_0-rmse:0.12736
# [487]	validation_0-rmse:0.12692
# [488]	validation_0-rmse:0.12649
# [489]	validation_0-rmse:0.12607
# [490]	validation_0-rmse:0.12565
# [491]	validation_0-rmse:0.12524
# [492]	validation_0-rmse:0.12482
# [493]	validation_0-rmse:0.12440
# [494]	validation_0-rmse:0.12401
# [495]	validation_0-rmse:0.12360
# [496]	validation_0-rmse:0.12321
# [497]	validation_0-rmse:0.12281
# [498]	validation_0-rmse:0.12241
# [499]	validation_0-rmse:0.12201
# [500]	validation_0-rmse:0.12161
# [501]	validation_0-rmse:0.12122
# [502]	validation_0-rmse:0.12082
# [503]	validation_0-rmse:0.12045
# [504]	validation_0-rmse:0.12005
# [505]	validation_0-rmse:0.11967
# [506]	validation_0-rmse:0.11930
# [507]	validation_0-rmse:0.11891
# [508]	validation_0-rmse:0.11853
# [509]	validation_0-rmse:0.11815
# [510]	validation_0-rmse:0.11779
# [511]	validation_0-rmse:0.11741
# [512]	validation_0-rmse:0.11704
# [513]	validation_0-rmse:0.11666
# [514]	validation_0-rmse:0.11630
# [515]	validation_0-rmse:0.11594
# [516]	validation_0-rmse:0.11557
# [517]	validation_0-rmse:0.11521
# [518]	validation_0-rmse:0.11485
# [519]	validation_0-rmse:0.11449
# [520]	validation_0-rmse:0.11415
# [521]	validation_0-rmse:0.11380
# [522]	validation_0-rmse:0.11344
# [523]	validation_0-rmse:0.11309
# [524]	validation_0-rmse:0.11274
# [525]	validation_0-rmse:0.11239
# [526]	validation_0-rmse:0.11205
# [527]	validation_0-rmse:0.11170
# [528]	validation_0-rmse:0.11137
# [529]	validation_0-rmse:0.11103
# [530]	validation_0-rmse:0.11070
# [531]	validation_0-rmse:0.11036
# [532]	validation_0-rmse:0.11003
# [533]	validation_0-rmse:0.10969
# [534]	validation_0-rmse:0.10936
# [535]	validation_0-rmse:0.10905
# [536]	validation_0-rmse:0.10873
# [537]	validation_0-rmse:0.10842
# [538]	validation_0-rmse:0.10810
# [539]	validation_0-rmse:0.10778
# [540]	validation_0-rmse:0.10748
# [541]	validation_0-rmse:0.10718
# [542]	validation_0-rmse:0.10687
# [543]	validation_0-rmse:0.10656
# [544]	validation_0-rmse:0.10624
# [545]	validation_0-rmse:0.10593
# [546]	validation_0-rmse:0.10562
# [547]	validation_0-rmse:0.10534
# [548]	validation_0-rmse:0.10504
# [549]	validation_0-rmse:0.10475
# [550]	validation_0-rmse:0.10444
# [551]	validation_0-rmse:0.10416
# [552]	validation_0-rmse:0.10386
# [553]	validation_0-rmse:0.10357
# [554]	validation_0-rmse:0.10327
# [555]	validation_0-rmse:0.10297
# [556]	validation_0-rmse:0.10270
# [557]	validation_0-rmse:0.10241
# [558]	validation_0-rmse:0.10212
# [559]	validation_0-rmse:0.10184
# [560]	validation_0-rmse:0.10155
# [561]	validation_0-rmse:0.10128
# [562]	validation_0-rmse:0.10100
# [563]	validation_0-rmse:0.10072
# [564]	validation_0-rmse:0.10044
# [565]	validation_0-rmse:0.10017
# [566]	validation_0-rmse:0.09989
# [567]	validation_0-rmse:0.09963
# [568]	validation_0-rmse:0.09937
# [569]	validation_0-rmse:0.09910
# [570]	validation_0-rmse:0.09883
# [571]	validation_0-rmse:0.09858
# [572]	validation_0-rmse:0.09832
# [573]	validation_0-rmse:0.09806
# [574]	validation_0-rmse:0.09779
# [575]	validation_0-rmse:0.09753
# [576]	validation_0-rmse:0.09727
# [577]	validation_0-rmse:0.09702
# [578]	validation_0-rmse:0.09676
# [579]	validation_0-rmse:0.09651
# [580]	validation_0-rmse:0.09625
# [581]	validation_0-rmse:0.09600
# [582]	validation_0-rmse:0.09575
# [583]	validation_0-rmse:0.09551
# [584]	validation_0-rmse:0.09528
# [585]	validation_0-rmse:0.09503
# [586]	validation_0-rmse:0.09479
# [587]	validation_0-rmse:0.09455
# [588]	validation_0-rmse:0.09432
# [589]	validation_0-rmse:0.09408
# [590]	validation_0-rmse:0.09386
# [591]	validation_0-rmse:0.09362
# [592]	validation_0-rmse:0.09339
# [593]	validation_0-rmse:0.09315
# [594]	validation_0-rmse:0.09292
# [595]	validation_0-rmse:0.09271
# [596]	validation_0-rmse:0.09248
# [597]	validation_0-rmse:0.09225
# [598]	validation_0-rmse:0.09204
# [599]	validation_0-rmse:0.09182
# [600]	validation_0-rmse:0.09160
# [601]	validation_0-rmse:0.09137
# [602]	validation_0-rmse:0.09116
# [603]	validation_0-rmse:0.09096
# [604]	validation_0-rmse:0.09075
# [605]	validation_0-rmse:0.09054
# [606]	validation_0-rmse:0.09033
# [607]	validation_0-rmse:0.09012
# [608]	validation_0-rmse:0.08992
# [609]	validation_0-rmse:0.08971
# [610]	validation_0-rmse:0.08951
# [611]	validation_0-rmse:0.08930
# [612]	validation_0-rmse:0.08911
# [613]	validation_0-rmse:0.08890
# [614]	validation_0-rmse:0.08871
# [615]	validation_0-rmse:0.08852
# [616]	validation_0-rmse:0.08832
# [617]	validation_0-rmse:0.08813
# [618]	validation_0-rmse:0.08795
# [619]	validation_0-rmse:0.08776
# [620]	validation_0-rmse:0.08756
# [621]	validation_0-rmse:0.08738
# [622]	validation_0-rmse:0.08718
# [623]	validation_0-rmse:0.08701
# [624]	validation_0-rmse:0.08682
# [625]	validation_0-rmse:0.08663
# [626]	validation_0-rmse:0.08646
# [627]	validation_0-rmse:0.08627
# [628]	validation_0-rmse:0.08609
# [629]	validation_0-rmse:0.08590
# [630]	validation_0-rmse:0.08572
# [631]	validation_0-rmse:0.08554
# [632]	validation_0-rmse:0.08536
# [633]	validation_0-rmse:0.08518
# [634]	validation_0-rmse:0.08501
# [635]	validation_0-rmse:0.08484
# [636]	validation_0-rmse:0.08467
# [637]	validation_0-rmse:0.08450
# [638]	validation_0-rmse:0.08432
# [639]	validation_0-rmse:0.08415
# [640]	validation_0-rmse:0.08398
# [641]	validation_0-rmse:0.08381
# [642]	validation_0-rmse:0.08365
# [643]	validation_0-rmse:0.08347
# [644]	validation_0-rmse:0.08332
# [645]	validation_0-rmse:0.08316
# [646]	validation_0-rmse:0.08299
# [647]	validation_0-rmse:0.08284
# [648]	validation_0-rmse:0.08268
# [649]	validation_0-rmse:0.08253
# [650]	validation_0-rmse:0.08237
# [651]	validation_0-rmse:0.08222
# [652]	validation_0-rmse:0.08206
# [653]	validation_0-rmse:0.08190
# [654]	validation_0-rmse:0.08176
# [655]	validation_0-rmse:0.08160
# [656]	validation_0-rmse:0.08144
# [657]	validation_0-rmse:0.08128
# [658]	validation_0-rmse:0.08113
# [659]	validation_0-rmse:0.08098
# [660]	validation_0-rmse:0.08084
# [661]	validation_0-rmse:0.08069
# [662]	validation_0-rmse:0.08054
# [663]	validation_0-rmse:0.08041
# [664]	validation_0-rmse:0.08026
# [665]	validation_0-rmse:0.08012
# [666]	validation_0-rmse:0.07998
# [667]	validation_0-rmse:0.07983
# [668]	validation_0-rmse:0.07969
# [669]	validation_0-rmse:0.07955
# [670]	validation_0-rmse:0.07941
# [671]	validation_0-rmse:0.07927
# [672]	validation_0-rmse:0.07913
# [673]	validation_0-rmse:0.07900
# [674]	validation_0-rmse:0.07886
# [675]	validation_0-rmse:0.07872
# [676]	validation_0-rmse:0.07858
# [677]	validation_0-rmse:0.07845
# [678]	validation_0-rmse:0.07831
# [679]	validation_0-rmse:0.07818
# [680]	validation_0-rmse:0.07806
# [681]	validation_0-rmse:0.07793
# [682]	validation_0-rmse:0.07779
# [683]	validation_0-rmse:0.07767
# [684]	validation_0-rmse:0.07755
# [685]	validation_0-rmse:0.07742
# [686]	validation_0-rmse:0.07729
# [687]	validation_0-rmse:0.07717
# [688]	validation_0-rmse:0.07705
# [689]	validation_0-rmse:0.07692
# [690]	validation_0-rmse:0.07680
# [691]	validation_0-rmse:0.07667
# [692]	validation_0-rmse:0.07655
# [693]	validation_0-rmse:0.07643
# [694]	validation_0-rmse:0.07631
# [695]	validation_0-rmse:0.07619
# [696]	validation_0-rmse:0.07608
# [697]	validation_0-rmse:0.07597
# [698]	validation_0-rmse:0.07585
# [699]	validation_0-rmse:0.07574
# [700]	validation_0-rmse:0.07562
# [701]	validation_0-rmse:0.07552
# [702]	validation_0-rmse:0.07541
# [785]	validation_0-rmse:0.06843
# [786]	validation_0-rmse:0.06837
# [787]	validation_0-rmse:0.06831
# [788]	validation_0-rmse:0.06825
# [789]	validation_0-rmse:0.06820
# [790]	validation_0-rmse:0.06813
# [791]	validation_0-rmse:0.06807
# [792]	validation_0-rmse:0.06802
# [793]	validation_0-rmse:0.06796
# [794]	validation_0-rmse:0.06791
# [795]	validation_0-rmse:0.06784
# [796]	validation_0-rmse:0.06779
# [797]	validation_0-rmse:0.06773
# [798]	validation_0-rmse:0.06768
# [799]	validation_0-rmse:0.06762
# [800]	validation_0-rmse:0.06757
# [801]	validation_0-rmse:0.06751
# [802]	validation_0-rmse:0.06745
# [803]	validation_0-rmse:0.06740
# [804]	validation_0-rmse:0.06734
# [805]	validation_0-rmse:0.06729
# [806]	validation_0-rmse:0.06723
# [807]	validation_0-rmse:0.06718
# [808]	validation_0-rmse:0.06712
# [809]	validation_0-rmse:0.06707
# [810]	validation_0-rmse:0.06702
# [811]	validation_0-rmse:0.06697
# [812]	validation_0-rmse:0.06692
# [813]	validation_0-rmse:0.06687
# [814]	validation_0-rmse:0.06682
# [815]	validation_0-rmse:0.06677
# [816]	validation_0-rmse:0.06672
# [817]	validation_0-rmse:0.06667
# [818]	validation_0-rmse:0.06662
# [819]	validation_0-rmse:0.06657
# [820]	validation_0-rmse:0.06652
# [821]	validation_0-rmse:0.06647
# [822]	validation_0-rmse:0.06642
# [823]	validation_0-rmse:0.06638
# [824]	validation_0-rmse:0.06633
# [825]	validation_0-rmse:0.06628
# [826]	validation_0-rmse:0.06624
# [827]	validation_0-rmse:0.06619
# [828]	validation_0-rmse:0.06615
# [829]	validation_0-rmse:0.06610
# [830]	validation_0-rmse:0.06607
# [831]	validation_0-rmse:0.06603
# [832]	validation_0-rmse:0.06599
# [833]	validation_0-rmse:0.06595
# [834]	validation_0-rmse:0.06591
# [835]	validation_0-rmse:0.06587
# [836]	validation_0-rmse:0.06582
# [837]	validation_0-rmse:0.06578
# [838]	validation_0-rmse:0.06574
# [839]	validation_0-rmse:0.06569
# [840]	validation_0-rmse:0.06565
# [841]	validation_0-rmse:0.06561
# [842]	validation_0-rmse:0.06557
# [843]	validation_0-rmse:0.06553
# [844]	validation_0-rmse:0.06549
# [845]	validation_0-rmse:0.06545
# [846]	validation_0-rmse:0.06541
# [847]	validation_0-rmse:0.06537
# [848]	validation_0-rmse:0.06533
# [849]	validation_0-rmse:0.06529
# [850]	validation_0-rmse:0.06525
# [851]	validation_0-rmse:0.06522
# [852]	validation_0-rmse:0.06518
# [853]	validation_0-rmse:0.06514
# [854]	validation_0-rmse:0.06510
# [855]	validation_0-rmse:0.06506
# [856]	validation_0-rmse:0.06503
# [857]	validation_0-rmse:0.06500
# [858]	validation_0-rmse:0.06496
# [859]	validation_0-rmse:0.06493
# [860]	validation_0-rmse:0.06489
# [861]	validation_0-rmse:0.06486
# [862]	validation_0-rmse:0.06482
# [863]	validation_0-rmse:0.06478
# [864]	validation_0-rmse:0.06475
# [865]	validation_0-rmse:0.06472
# [866]	validation_0-rmse:0.06469
# [867]	validation_0-rmse:0.06466
# [868]	validation_0-rmse:0.06463
# [869]	validation_0-rmse:0.06460
# [870]	validation_0-rmse:0.06456
# [871]	validation_0-rmse:0.06453
# [872]	validation_0-rmse:0.06450
# [873]	validation_0-rmse:0.06446
# [874]	validation_0-rmse:0.06443
# [875]	validation_0-rmse:0.06440
# [876]	validation_0-rmse:0.06437
# [877]	validation_0-rmse:0.06434
# [878]	validation_0-rmse:0.06430
# [879]	validation_0-rmse:0.06427
# [880]	validation_0-rmse:0.06424
# [881]	validation_0-rmse:0.06421
# [882]	validation_0-rmse:0.06418
# [883]	validation_0-rmse:0.06415
# [884]	validation_0-rmse:0.06412
# [885]	validation_0-rmse:0.06409
# [886]	validation_0-rmse:0.06407
# [887]	validation_0-rmse:0.06404
# [888]	validation_0-rmse:0.06401
# [889]	validation_0-rmse:0.06399
# [890]	validation_0-rmse:0.06396
# [891]	validation_0-rmse:0.06393
# [892]	validation_0-rmse:0.06391
# [893]	validation_0-rmse:0.06388
# [894]	validation_0-rmse:0.06385
# [895]	validation_0-rmse:0.06382
# [896]	validation_0-rmse:0.06379
# [897]	validation_0-rmse:0.06376
# [898]	validation_0-rmse:0.06374
# [899]	validation_0-rmse:0.06371
# [900]	validation_0-rmse:0.06368
# [901]	validation_0-rmse:0.06366
# [902]	validation_0-rmse:0.06363
# [903]	validation_0-rmse:0.06360
# [904]	validation_0-rmse:0.06358
# [905]	validation_0-rmse:0.06355
# [906]	validation_0-rmse:0.06352
# [907]	validation_0-rmse:0.06350
# [908]	validation_0-rmse:0.06347
# [909]	validation_0-rmse:0.06345
# [910]	validation_0-rmse:0.06342
# [911]	validation_0-rmse:0.06339
# [912]	validation_0-rmse:0.06337
# [913]	validation_0-rmse:0.06334
# [914]	validation_0-rmse:0.06332
# [915]	validation_0-rmse:0.06330
# [916]	validation_0-rmse:0.06327
# [917]	validation_0-rmse:0.06325
# [918]	validation_0-rmse:0.06323
# [919]	validation_0-rmse:0.06320
# [920]	validation_0-rmse:0.06318
# [921]	validation_0-rmse:0.06316
# [922]	validation_0-rmse:0.06314
# [923]	validation_0-rmse:0.06312
# [924]	validation_0-rmse:0.06310
# [925]	validation_0-rmse:0.06308
# [926]	validation_0-rmse:0.06306
# [927]	validation_0-rmse:0.06304
# [928]	validation_0-rmse:0.06302
# [929]	validation_0-rmse:0.06300
# [930]	validation_0-rmse:0.06297
# [931]	validation_0-rmse:0.06295
# [932]	validation_0-rmse:0.06293
# [933]	validation_0-rmse:0.06291
# [934]	validation_0-rmse:0.06289
# [935]	validation_0-rmse:0.06286
# [936]	validation_0-rmse:0.06284
# [937]	validation_0-rmse:0.06282
# [938]	validation_0-rmse:0.06281
# [939]	validation_0-rmse:0.06279
# [940]	validation_0-rmse:0.06277
# [941]	validation_0-rmse:0.06275
# [942]	validation_0-rmse:0.06273
# [943]	validation_0-rmse:0.06272
# [944]	validation_0-rmse:0.06270
# [945]	validation_0-rmse:0.06268
# [946]	validation_0-rmse:0.06266
# [947]	validation_0-rmse:0.06264
# [948]	validation_0-rmse:0.06262
# [949]	validation_0-rmse:0.06260
# [950]	validation_0-rmse:0.06258
# [951]	validation_0-rmse:0.06257
# [952]	validation_0-rmse:0.06255
# [953]	validation_0-rmse:0.06253
# [954]	validation_0-rmse:0.06251
# [955]	validation_0-rmse:0.06249
# [956]	validation_0-rmse:0.06248
# [957]	validation_0-rmse:0.06246
# [958]	validation_0-rmse:0.06244
# [959]	validation_0-rmse:0.06242
# [960]	validation_0-rmse:0.06241
# [961]	validation_0-rmse:0.06239
# [962]	validation_0-rmse:0.06238
# [963]	validation_0-rmse:0.06236
# [964]	validation_0-rmse:0.06234
# [965]	validation_0-rmse:0.06233
# [966]	validation_0-rmse:0.06231
# [967]	validation_0-rmse:0.06230
# [968]	validation_0-rmse:0.06228
# [969]	validation_0-rmse:0.06227
# [970]	validation_0-rmse:0.06225
# [971]	validation_0-rmse:0.06224
# [972]	validation_0-rmse:0.06222
# [973]	validation_0-rmse:0.06221
# [974]	validation_0-rmse:0.06219
# [975]	validation_0-rmse:0.06218
# [976]	validation_0-rmse:0.06216
# [977]	validation_0-rmse:0.06215
# [978]	validation_0-rmse:0.06213
# [979]	validation_0-rmse:0.06212
# [980]	validation_0-rmse:0.06210
# [981]	validation_0-rmse:0.06209
# [982]	validation_0-rmse:0.06207
# [983]	validation_0-rmse:0.06206
# [984]	validation_0-rmse:0.06204
# [985]	validation_0-rmse:0.06203
# [986]	validation_0-rmse:0.06202
# [987]	validation_0-rmse:0.06200
# [988]	validation_0-rmse:0.06199
# [989]	validation_0-rmse:0.06198
# [990]	validation_0-rmse:0.06196
# [991]	validation_0-rmse:0.06195
# [992]	validation_0-rmse:0.06194
# [993]	validation_0-rmse:0.06192
# [994]	validation_0-rmse:0.06191
# [995]	validation_0-rmse:0.06190
# [996]	validation_0-rmse:0.06189
# [997]	validation_0-rmse:0.06187
# [998]	validation_0-rmse:0.06186
# [999]	validation_0-rmse:0.06184
# [1000]	validation_0-rmse:0.06183
# [1001]	validation_0-rmse:0.06182
# [1002]	validation_0-rmse:0.06181
# [1003]	validation_0-rmse:0.06180
# [1004]	validation_0-rmse:0.06179
# [1005]	validation_0-rmse:0.06178
# [1006]	validation_0-rmse:0.06176
# [1007]	validation_0-rmse:0.06175
# [1008]	validation_0-rmse:0.06174
# [1009]	validation_0-rmse:0.06172
# [1010]	validation_0-rmse:0.06171
# [1011]	validation_0-rmse:0.06170
# [1012]	validation_0-rmse:0.06169
# [1013]	validation_0-rmse:0.06168
# [1014]	validation_0-rmse:0.06167
# [1015]	validation_0-rmse:0.06166
# [1016]	validation_0-rmse:0.06165
# [1017]	validation_0-rmse:0.06164
# [1018]	validation_0-rmse:0.06163
# [1019]	validation_0-rmse:0.06162
# [1020]	validation_0-rmse:0.06161
# [1021]	validation_0-rmse:0.06159
# [1022]	validation_0-rmse:0.06158
# [1023]	validation_0-rmse:0.06157
# [1024]	validation_0-rmse:0.06156
# [1025]	validation_0-rmse:0.06155
# [1026]	validation_0-rmse:0.06155
# [1027]	validation_0-rmse:0.06153
# [1028]	validation_0-rmse:0.06153
# [1029]	validation_0-rmse:0.06152
# [1186]	validation_0-rmse:0.06055
# [1187]	validation_0-rmse:0.06055
# [1188]	validation_0-rmse:0.06054
# [1189]	validation_0-rmse:0.06054
# [1190]	validation_0-rmse:0.06054
# [1191]	validation_0-rmse:0.06053
# [1192]	validation_0-rmse:0.06053
# [1193]	validation_0-rmse:0.06052
# [1194]	validation_0-rmse:0.06052
# [1195]	validation_0-rmse:0.06052
# [1196]	validation_0-rmse:0.06051
# [1197]	validation_0-rmse:0.06051
# [1198]	validation_0-rmse:0.06051
# [1199]	validation_0-rmse:0.06050
# [1200]	validation_0-rmse:0.06050
# [1201]	validation_0-rmse:0.06050
# [1202]	validation_0-rmse:0.06049
# [1203]	validation_0-rmse:0.06049
# [1204]	validation_0-rmse:0.06049
# [1205]	validation_0-rmse:0.06048
# [1206]	validation_0-rmse:0.06048
# [1207]	validation_0-rmse:0.06048
# [1208]	validation_0-rmse:0.06048
# [1209]	validation_0-rmse:0.06047
# [1210]	validation_0-rmse:0.06047
# [1211]	validation_0-rmse:0.06047
# [1212]	validation_0-rmse:0.06047
# [1213]	validation_0-rmse:0.06046
# [1214]	validation_0-rmse:0.06046
# [1215]	validation_0-rmse:0.06046
# [1216]	validation_0-rmse:0.06045
# [1217]	validation_0-rmse:0.06045
# [1218]	validation_0-rmse:0.06045
# [1219]	validation_0-rmse:0.06045
# [1220]	validation_0-rmse:0.06044
# [1221]	validation_0-rmse:0.06044
# [1222]	validation_0-rmse:0.06044
# [1223]	validation_0-rmse:0.06043
# [1224]	validation_0-rmse:0.06043
# [1225]	validation_0-rmse:0.06043
# [1226]	validation_0-rmse:0.06043
# [1227]	validation_0-rmse:0.06043
# [1228]	validation_0-rmse:0.06042
# [1229]	validation_0-rmse:0.06042
# [1230]	validation_0-rmse:0.06042
# [1231]	validation_0-rmse:0.06042
# [1232]	validation_0-rmse:0.06041
# [1233]	validation_0-rmse:0.06041
# [1234]	validation_0-rmse:0.06041
# [1235]	validation_0-rmse:0.06041
# [1236]	validation_0-rmse:0.06040
# [1237]	validation_0-rmse:0.06040
# [1238]	validation_0-rmse:0.06040
# [1239]	validation_0-rmse:0.06040
# [1240]	validation_0-rmse:0.06039
# [1241]	validation_0-rmse:0.06039
# [1242]	validation_0-rmse:0.06039
# [1243]	validation_0-rmse:0.06039
# [1244]	validation_0-rmse:0.06038
# [1245]	validation_0-rmse:0.06038
# [1246]	validation_0-rmse:0.06038
# [1247]	validation_0-rmse:0.06038
# [1248]	validation_0-rmse:0.06037
# [1249]	validation_0-rmse:0.06037
# [1250]	validation_0-rmse:0.06037
# [1251]	validation_0-rmse:0.06037
# [1252]	validation_0-rmse:0.06037
# [1253]	validation_0-rmse:0.06037
# [1254]	validation_0-rmse:0.06036
# [1255]	validation_0-rmse:0.06036
# [1256]	validation_0-rmse:0.06036
# [1257]	validation_0-rmse:0.06036
# [1258]	validation_0-rmse:0.06036
# [1259]	validation_0-rmse:0.06035
# [1260]	validation_0-rmse:0.06035
# [1261]	validation_0-rmse:0.06035
# [1262]	validation_0-rmse:0.06035
# [1263]	validation_0-rmse:0.06035
# [1649]	validation_0-rmse:0.06005
# [1650]	validation_0-rmse:0.06005
# [1651]	validation_0-rmse:0.06005
# [1652]	validation_0-rmse:0.06005
# [1653]	validation_0-rmse:0.06005
# [1654]	validation_0-rmse:0.06005
# [1655]	validation_0-rmse:0.06004
# [1656]	validation_0-rmse:0.06004
# [1657]	validation_0-rmse:0.06004
# [1658]	validation_0-rmse:0.06004
# [1659]	validation_0-rmse:0.06004
# [1660]	validation_0-rmse:0.06004
# [1661]	validation_0-rmse:0.06004
# [1662]	validation_0-rmse:0.06004
# [1663]	validation_0-rmse:0.06004
# [1664]	validation_0-rmse:0.06004
# [1665]	validation_0-rmse:0.06004
# [1666]	validation_0-rmse:0.06004
# [1667]	validation_0-rmse:0.06004
# [1668]	validation_0-rmse:0.06004
# [1669]	validation_0-rmse:0.06004
# [1670]	validation_0-rmse:0.06004
# [1671]	validation_0-rmse:0.06004
# [1672]	validation_0-rmse:0.06004
# [1673]	validation_0-rmse:0.06004
# [1674]	validation_0-rmse:0.06004
# [1675]	validation_0-rmse:0.06004
# [1676]	validation_0-rmse:0.06004
# [1677]	validation_0-rmse:0.06004
# [1678]	validation_0-rmse:0.06004
# [1679]	validation_0-rmse:0.06004
# [1680]	validation_0-rmse:0.06004
# [1681]	validation_0-rmse:0.06004
# [1682]	validation_0-rmse:0.06004
# [1683]	validation_0-rmse:0.06004
# [1684]	validation_0-rmse:0.06004
# [1685]	validation_0-rmse:0.06003
# [1686]	validation_0-rmse:0.06003
# [1687]	validation_0-rmse:0.06003
# [1688]	validation_0-rmse:0.06003
# [1689]	validation_0-rmse:0.06003
# [1690]	validation_0-rmse:0.06003
# [1691]	validation_0-rmse:0.06003
# [1692]	validation_0-rmse:0.06003
# [1693]	validation_0-rmse:0.06003
# [1694]	validation_0-rmse:0.06003
# [1695]	validation_0-rmse:0.06003
# [1696]	validation_0-rmse:0.06003
# [1697]	validation_0-rmse:0.06003
# [1698]	validation_0-rmse:0.06003
# [1699]	validation_0-rmse:0.06003
# [1700]	validation_0-rmse:0.06003
# [1701]	validation_0-rmse:0.06003
# [1702]	validation_0-rmse:0.06003
# [1703]	validation_0-rmse:0.06003
# [1704]	validation_0-rmse:0.06003
# [1705]	validation_0-rmse:0.06003
# [1706]	validation_0-rmse:0.06003
# [1707]	validation_0-rmse:0.06003
# [1708]	validation_0-rmse:0.06003
# [1709]	validation_0-rmse:0.06003
# [1710]	validation_0-rmse:0.06003
# [1711]	validation_0-rmse:0.06003
# [1712]	validation_0-rmse:0.06003
# [1713]	validation_0-rmse:0.06003
# [1714]	validation_0-rmse:0.06003
# [1715]	validation_0-rmse:0.06003
# [1716]	validation_0-rmse:0.06003
# [1717]	validation_0-rmse:0.06003
# [1718]	validation_0-rmse:0.06003
# [1719]	validation_0-rmse:0.06003
# [1720]	validation_0-rmse:0.06003
# [1721]	validation_0-rmse:0.06003
# [1722]	validation_0-rmse:0.06003
# [1723]	validation_0-rmse:0.06003
# [1724]	validation_0-rmse:0.06003
# [1725]	validation_0-rmse:0.06003
# [1726]	validation_0-rmse:0.06003
# [1727]	validation_0-rmse:0.06003
# [1728]	validation_0-rmse:0.06003
# [1729]	validation_0-rmse:0.06003
# [1730]	validation_0-rmse:0.06003
# [1731]	validation_0-rmse:0.06003
# [1732]	validation_0-rmse:0.06003
# [1733]	validation_0-rmse:0.06003
# [1734]	validation_0-rmse:0.06003
# [1735]	validation_0-rmse:0.06003
# [1736]	validation_0-rmse:0.06003
# [1737]	validation_0-rmse:0.06003
# [1738]	validation_0-rmse:0.06003
# [1739]	validation_0-rmse:0.06003
# [1740]	validation_0-rmse:0.06003
# [1741]	validation_0-rmse:0.06003
# [1742]	validation_0-rmse:0.06003
# [1743]	validation_0-rmse:0.06003
# [1744]	validation_0-rmse:0.06003
# [1745]	validation_0-rmse:0.06003
# [1746]	validation_0-rmse:0.06003
# [1747]	validation_0-rmse:0.06003
# [1748]	validation_0-rmse:0.06002
# [1749]	validation_0-rmse:0.06002
# [1750]	validation_0-rmse:0.06002
# [1751]	validation_0-rmse:0.06002
# [1752]	validation_0-rmse:0.06003
# [1753]	validation_0-rmse:0.06002
# [1754]	validation_0-rmse:0.06002
# [1755]	validation_0-rmse:0.06002
# [1756]	validation_0-rmse:0.06002
# [1757]	validation_0-rmse:0.06002
# [1758]	validation_0-rmse:0.06002
# [1759]	validation_0-rmse:0.06003
# [1760]	validation_0-rmse:0.06003
# [1761]	validation_0-rmse:0.06002
# [1762]	validation_0-rmse:0.06002
# [1763]	validation_0-rmse:0.06002
# [1764]	validation_0-rmse:0.06002
# [1765]	validation_0-rmse:0.06002
# [1766]	validation_0-rmse:0.06002
# [1767]	validation_0-rmse:0.06002
# [1768]	validation_0-rmse:0.06002
# [1769]	validation_0-rmse:0.06002
# [1770]	validation_0-rmse:0.06002
# [1771]	validation_0-rmse:0.06002
# [1772]	validation_0-rmse:0.06002
# [1773]	validation_0-rmse:0.06002
# [1774]	validation_0-rmse:0.06002
# [1775]	validation_0-rmse:0.06002
# [1776]	validation_0-rmse:0.06002
# [1777]	validation_0-rmse:0.06002
# [1778]	validation_0-rmse:0.06002
# [1779]	validation_0-rmse:0.06002
# [1780]	validation_0-rmse:0.06002
# [1781]	validation_0-rmse:0.06002
# [1782]	validation_0-rmse:0.06002
# [1783]	validation_0-rmse:0.06002
# [1784]	validation_0-rmse:0.06002
# [1785]	validation_0-rmse:0.06002
# [1786]	validation_0-rmse:0.06002
# [1787]	validation_0-rmse:0.06002
# [1788]	validation_0-rmse:0.06002
# [1789]	validation_0-rmse:0.06002
# [1790]	validation_0-rmse:0.06002
# [1791]	validation_0-rmse:0.06002
# [1792]	validation_0-rmse:0.06002
# [1793]	validation_0-rmse:0.06002
# [1794]	validation_0-rmse:0.06002
# [1795]	validation_0-rmse:0.06002
# [1796]	validation_0-rmse:0.06002
# [1797]	validation_0-rmse:0.06002
# [1798]	validation_0-rmse:0.06002
# [1799]	validation_0-rmse:0.06002
# [1800]	validation_0-rmse:0.06002
# [1801]	validation_0-rmse:0.06002
# [1802]	validation_0-rmse:0.06002
# [1803]	validation_0-rmse:0.06002
# [1804]	validation_0-rmse:0.06002
# [1805]	validation_0-rmse:0.06002
# [1806]	validation_0-rmse:0.06002
# [1807]	validation_0-rmse:0.06002
# [1808]	validation_0-rmse:0.06002
# [1809]	validation_0-rmse:0.06002
# [1810]	validation_0-rmse:0.06002
# [1811]	validation_0-rmse:0.06002
# [1812]	validation_0-rmse:0.06002
# [1813]	validation_0-rmse:0.06002
# [1814]	validation_0-rmse:0.06002
# [1815]	validation_0-rmse:0.06002
# [1816]	validation_0-rmse:0.06002
# [1817]	validation_0-rmse:0.06002
# [1818]	validation_0-rmse:0.06002
# [1819]	validation_0-rmse:0.06002
# [1820]	validation_0-rmse:0.06002
# [1821]	validation_0-rmse:0.06002
# [1822]	validation_0-rmse:0.06002
# [1823]	validation_0-rmse:0.06002
# [1824]	validation_0-rmse:0.06002
# [1825]	validation_0-rmse:0.06002
# [1826]	validation_0-rmse:0.06002
# [1827]	validation_0-rmse:0.06002
# [1828]	validation_0-rmse:0.06002
# [1829]	validation_0-rmse:0.06002
# [1830]	validation_0-rmse:0.06002
# [1831]	validation_0-rmse:0.06002
# [1832]	validation_0-rmse:0.06002
# [1833]	validation_0-rmse:0.06002
# [1834]	validation_0-rmse:0.06002
# [1835]	validation_0-rmse:0.06002
# [1836]	validation_0-rmse:0.06002
# [1837]	validation_0-rmse:0.06002
# [1838]	validation_0-rmse:0.06002
# [1839]	validation_0-rmse:0.06002
# [1840]	validation_0-rmse:0.06002
# [1841]	validation_0-rmse:0.06002
# [1842]	validation_0-rmse:0.06002
# [1843]	validation_0-rmse:0.06001
# [1844]	validation_0-rmse:0.06001
# [1845]	validation_0-rmse:0.06001
# [1846]	validation_0-rmse:0.06001
# [1847]	validation_0-rmse:0.06001
# [1848]	validation_0-rmse:0.06001
# [1849]	validation_0-rmse:0.06001
# [1850]	validation_0-rmse:0.06001
# [1851]	validation_0-rmse:0.06001
# [1852]	validation_0-rmse:0.06001
# [1853]	validation_0-rmse:0.06001
# [1854]	validation_0-rmse:0.06001
# [1855]	validation_0-rmse:0.06001
# [1856]	validation_0-rmse:0.06001
# [1857]	validation_0-rmse:0.06001
# [1858]	validation_0-rmse:0.06001
# [1859]	validation_0-rmse:0.06001
# [1860]	validation_0-rmse:0.06001
# [1861]	validation_0-rmse:0.06001
# [1862]	validation_0-rmse:0.06001
# [1863]	validation_0-rmse:0.06001
# [1864]	validation_0-rmse:0.06001
# [1865]	validation_0-rmse:0.06001
# [1866]	validation_0-rmse:0.06001
# [1867]	validation_0-rmse:0.06001
# [1868]	validation_0-rmse:0.06001
# [1869]	validation_0-rmse:0.06001
# [1870]	validation_0-rmse:0.06001
# [1871]	validation_0-rmse:0.06001
# [1872]	validation_0-rmse:0.06001
# [1873]	validation_0-rmse:0.06001
# [1874]	validation_0-rmse:0.06001
# [1875]	validation_0-rmse:0.06001
# [1876]	validation_0-rmse:0.06001
# [1877]	validation_0-rmse:0.06001
# [1878]	validation_0-rmse:0.06001
# [1879]	validation_0-rmse:0.06001
# [1880]	validation_0-rmse:0.06001
# [1881]	validation_0-rmse:0.06001
# [1882]	validation_0-rmse:0.06001
# [1883]	validation_0-rmse:0.06001
# [1884]	validation_0-rmse:0.06001
# [1885]	validation_0-rmse:0.06001
# [1886]	validation_0-rmse:0.06001
# [1887]	validation_0-rmse:0.06001
# [1888]	validation_0-rmse:0.06001
# [1889]	validation_0-rmse:0.06001
# [1890]	validation_0-rmse:0.06001
# [1891]	validation_0-rmse:0.06001
# [1892]	validation_0-rmse:0.06001
# [1893]	validation_0-rmse:0.06001
# [1894]	validation_0-rmse:0.06001
# [1895]	validation_0-rmse:0.06001
# [1896]	validation_0-rmse:0.06001
# [1897]	validation_0-rmse:0.06001
# [1898]	validation_0-rmse:0.06001
# [1899]	validation_0-rmse:0.06001
# [1900]	validation_0-rmse:0.06001
# [1901]	validation_0-rmse:0.06001
# [1902]	validation_0-rmse:0.06001
# [1903]	validation_0-rmse:0.06001
# [1904]	validation_0-rmse:0.06001
# [1905]	validation_0-rmse:0.06001
# [1906]	validation_0-rmse:0.06001
# [1907]	validation_0-rmse:0.06001
# [1908]	validation_0-rmse:0.06001
# [1909]	validation_0-rmse:0.06001
# [1910]	validation_0-rmse:0.06001
# [1911]	validation_0-rmse:0.06001
# [1912]	validation_0-rmse:0.06001
# [1913]	validation_0-rmse:0.06001
# [1914]	validation_0-rmse:0.06001
# [1915]	validation_0-rmse:0.06001
# [1916]	validation_0-rmse:0.06001
# [1917]	validation_0-rmse:0.06001
# [1918]	validation_0-rmse:0.06001
# [1919]	validation_0-rmse:0.06001
# [1920]	validation_0-rmse:0.06001
# [1921]	validation_0-rmse:0.06001
# [1922]	validation_0-rmse:0.06001
# [1923]	validation_0-rmse:0.06001
# [1924]	validation_0-rmse:0.06001
# [1925]	validation_0-rmse:0.06001
# [1926]	validation_0-rmse:0.06001
# [1927]	validation_0-rmse:0.06001
# [1928]	validation_0-rmse:0.06001
# [1929]	validation_0-rmse:0.06001
# [1930]	validation_0-rmse:0.06001
# [1931]	validation_0-rmse:0.06001
# [1932]	validation_0-rmse:0.06001
# [1933]	validation_0-rmse:0.06001
# [1934]	validation_0-rmse:0.06001
# [1935]	validation_0-rmse:0.06001
# [1936]	validation_0-rmse:0.06001
# [1937]	validation_0-rmse:0.06001
# [1938]	validation_0-rmse:0.06001
# [1939]	validation_0-rmse:0.06000
# [1940]	validation_0-rmse:0.06001
# [1941]	validation_0-rmse:0.06001
# [1942]	validation_0-rmse:0.06001
# [1943]	validation_0-rmse:0.06000
# [1944]	validation_0-rmse:0.06000
# [1945]	validation_0-rmse:0.06000
# [1946]	validation_0-rmse:0.06000
# [1947]	validation_0-rmse:0.06000
# [1948]	validation_0-rmse:0.06000
# [1949]	validation_0-rmse:0.06000
# [1950]	validation_0-rmse:0.06000
# [1951]	validation_0-rmse:0.06000
# [1952]	validation_0-rmse:0.06000
# [1953]	validation_0-rmse:0.06000
# [1954]	validation_0-rmse:0.06000
# [1955]	validation_0-rmse:0.06000
# [1956]	validation_0-rmse:0.06000
# [1957]	validation_0-rmse:0.06000
# [1958]	validation_0-rmse:0.06000
# [1959]	validation_0-rmse:0.06000
# [1960]	validation_0-rmse:0.06000
# [1961]	validation_0-rmse:0.06000
# [1962]	validation_0-rmse:0.06000
# [1963]	validation_0-rmse:0.06000
# [1964]	validation_0-rmse:0.06000
# [1965]	validation_0-rmse:0.06000
# [1966]	validation_0-rmse:0.06000
# [1967]	validation_0-rmse:0.06000
# [1968]	validation_0-rmse:0.06000
# [1969]	validation_0-rmse:0.06000
# [1970]	validation_0-rmse:0.06000
# [1971]	validation_0-rmse:0.06000
# [1972]	validation_0-rmse:0.06000
# [1973]	validation_0-rmse:0.06000
# [1974]	validation_0-rmse:0.06000
# [1975]	validation_0-rmse:0.06000
# [1976]	validation_0-rmse:0.06000
# [1977]	validation_0-rmse:0.06000
# [1978]	validation_0-rmse:0.06000
# [1979]	validation_0-rmse:0.06000
# [1980]	validation_0-rmse:0.06000
# [1981]	validation_0-rmse:0.06000
# [1982]	validation_0-rmse:0.06000
# [1983]	validation_0-rmse:0.06000
# [1984]	validation_0-rmse:0.06000
# [1985]	validation_0-rmse:0.06000
# [1986]	validation_0-rmse:0.06000
# [1987]	validation_0-rmse:0.06000
# [1988]	validation_0-rmse:0.06000
# [1989]	validation_0-rmse:0.06000
# [1990]	validation_0-rmse:0.06000
# [1991]	validation_0-rmse:0.06000
# [1992]	validation_0-rmse:0.06000
# [1993]	validation_0-rmse:0.06000
# [1994]	validation_0-rmse:0.06000
# [1995]	validation_0-rmse:0.06000
# [1996]	validation_0-rmse:0.06000
# [1997]	validation_0-rmse:0.06000
# [1998]	validation_0-rmse:0.06000
# [1999]	validation_0-rmse:0.06000
# Numero ottimale di boosting rounds: 1999
# Hold-out → RMSE: 3.6234, RMSLE: 0.0600
#
# Addestramento modelli CV ensemble...
#
# Training fold 1/10
# Fold 1 RMSLE: 0.0600
#
# Training fold 2/10
# Fold 2 RMSLE: 0.0586
#
# Training fold 3/10
# Fold 3 RMSLE: 0.0616
#
# Training fold 4/10
# Fold 4 RMSLE: 0.0592
#
# Training fold 5/10
# Fold 5 RMSLE: 0.0590
#
# Training fold 6/10
# Fold 6 RMSLE: 0.0603
#
# Training fold 7/10
# Fold 7 RMSLE: 0.0590
#
# Training fold 8/10
# Fold 8 RMSLE: 0.0606
#
# Training fold 9/10
# Fold 9 RMSLE: 0.0599
#
# Training fold 10/10
# Fold 10 RMSLE: 0.0587
#
# Out-of-fold RMSLE: 1.2893
#
# Top 10 feature importances:
#              Feature  Importance
# 0  Heart_Beats_Total    0.550375
# 1           Duration    0.399946
# 2        HBT_per_BSA    0.028128
# 3     BMI_x_Duration    0.005907
# 4                Age    0.005314
# 5                Sex    0.004082
# 6         Heart_Rate    0.003510
# 7             Weight    0.000812
# 8          Body_Temp    0.000703
# 9          HR_per_kg    0.000497
#
# Preview delle predizioni:
#        id  Pred_Calories
# 0  750000      27.208603
# 1  750001     107.898094
# 2  750002      87.506927
# 3  750003     126.272522
# 4  750004      75.592270
#
# Creato file pronto per il submit con ensemble CV!

# %%
import time
from google.colab import runtime

print("Il runtime verrà interrotto tra 30 secondi...")
time.sleep(30)
runtime.unassign()
# Out:
# Il runtime verrà interrotto tra 30 secondi...
